# %% [markdown]
# # Welcome to an introductory Jupyter notebook.
#
# We'll use Jupyter notebooks for simple, interactive database examples.
#
# This sample illustrates what you can do with a Jupyter notebook and checks that you've installed everything correctly.

# %% [markdown]
# ## Example 1: Running provided code
#
# The following item is a "cell".  Each cell has two parts.  An input box is labeled "In []:", and it may contain code that we have provided.  Once this code is run, its output will appear below the input box.  Both are nicely formatted.
#
# To run the code, click on it, and press SHIFT+ENTER.

# %%
# Some Python 3 code
print (str.join("",["H","e","ll","o"," ","wor","l","d!"]))
print ("COMP", 43*2*5)
# Out:
# Hello world!
# COMP 430

# %% [markdown]
# ## Example 2: Editing provided code
#
# Click in the next code box, and edit it to print your own name.  Run it.
#
# Any change to the notebook, including displaying code output, is automatically saved to the original notebook file on your computer.

# %%
print ("Gino Liao")
# Out:
# Gino Liao

# %% [markdown]
# ## Example 3: Adding a cell
#
# Click on this cell, then press the "+" button above.  You'll create a new cell.  By default, the cell will contain code, as indicated in a pull-down menu above.
#
# Type some code, and run it.  Or alternatively, change the pull-down menu to "Markdown", and type in some text.  Text can be formatted in the standard Markdown way.  You'll never need to do anything beyond just typing text, but you can search online for documentation.

# %%
print("cell")
# Out:
# cell

# %% [markdown]
# ## Example 4: Connecting to PostgreSQL
#
# First, we have to load the ipython-sql extension that you should have installed.
#
# We'll use "%load_ext", which is an example of IPython/Jupyter "line magic", i.e., basically a special command to the Python interpreter.

# %%
# %load_ext sql
# Out:
# C:\Users\Zilong\Anaconda3\lib\site-packages\IPython\config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# C:\Users\Zilong\Anaconda3\lib\site-packages\IPython\utils\traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %% [markdown]
# You will probably get a red-highlighted warning that part of the package has been deprecated.  Ignore that.  However, if you get a stack trace saying that sql is not an IPython extension, you haven't installed ipython-sql correctly.
#
# Next, we'll connect to PostgreSQL as the user ricerdb that you should have created.  Again, IPython/Jupyter provides a special line magic command for SQL database commands.  Change YOURPASSWORD to the password you chose for ricedb.

# %%
# %sql postgresql://ricedb:zl15ricedb@localhost/postgres
# Out:
# 'Connected: ricedb@postgres'

# %%
# %%sql
# DROP TABLE IF EXISTS Org CASCADE;
# Out:
# (psycopg2.ProgrammingError) must be owner of relation org
#  [SQL: 'DROP TABLE IF EXISTS Org CASCADE;']

# %%
# %%sql
#
# DROP TABLE IF EXISTS Org CASCADE;
# DROP TABLE IF EXISTS Meet CASCADE;
# DROP TABLE IF EXISTS Participant CASCADE;
# DROP TABLE IF EXISTS Leg CASCADE;
# DROP TABLE IF EXISTS Stroke CASCADE;
# DROP TABLE IF EXISTS Distance CASCADE;
# DROP TABLE IF EXISTS Event CASCADE;
# DROP TABLE IF EXISTS StrokeOf CASCADE;
# DROP TABLE IF EXISTS Heat CASCADE;
# DROP TABLE IF EXISTS Swim CASCADE;
#
# CREATE TABLE Org (
#     id VARCHAR(10),
#     name VARCHAR(20),
#     is_univ BOOLEAN,
#     PRIMARY KEY (id),
#     --one name corresponds to only one org or one university
#     --dont allow two ids with same name that one is a univ and another is an org
#     CONSTRAINT un_name_is_univ UNIQUE(name, is_univ)
# );
#
# CREATE TABLE Meet (
#     name VARCHAR(20),
#     start_date DATE,
#     num_days INT,	--can be unknown
#     org_id VARCHAR(10),
#     PRIMARY KEY (name),
#     FOREIGN KEY (org_id) REFERENCES Org (id),
#     CONSTRAINT chk_num_days
#     CHECK (num_days > 0)
# );
#
#
# CREATE TABLE Participant (
#     id VARCHAR(10),
#     gender VARCHAR(1) NOT NULL,
#     org_id VARCHAR(10) NOT NULL,
#     name VARCHAR(20),
#     PRIMARY KEY (id),
#     FOREIGN KEY (org_id) REFERENCES Org (id),
#     CONSTRAINT chk_gender CHECK (gender IN ('M', 'F'))
# );
#
# CREATE TABLE Leg (
#     leg INT,
#     PRIMARY KEY (leg),
#     CONSTRAINT chk_leg CHECK (leg > 0)
# );
#
# CREATE TABLE Stroke (
#     stroke VARCHAR(20),
#     PRIMARY KEY (stroke),
#     --limit stroke to lower case, so the application should convert string to lowercase
#     CONSTRAINT chk_stroke CHECK (stroke IN ('freestyle', 'butterfly', 'breaststroke', 'backstroke', 'medley'))
# );
#
# CREATE TABLE Distance (
#     distance INT,
#     PRIMARY KEY (distance),
#     --limit distance to hundreds
#     CONSTRAINT chk_distance CHECK (distance IN (100, 200, 400))
# );
#
#
# CREATE TABLE Event (
#     id VARCHAR(10),
#     gender VARCHAR(1) NOT NULL,
#     distance INT NOT NULL,
#     PRIMARY KEY (id),
#     FOREIGN KEY (distance) REFERENCES Distance (distance),
#     CONSTRAINT chk_gender CHECK (gender IN ('M', 'F'))
# );
#
# CREATE TABLE StrokeOf (
#     event_id VARCHAR(10),
#     leg INT,
#     stroke VARCHAR(20) NOT NULL,
#     PRIMARY KEY (event_id, leg),
#     FOREIGN KEY (event_id) REFERENCES Event (id),
#     FOREIGN KEY (leg) REFERENCES Leg (leg),
#     FOREIGN KEY (stroke) REFERENCES Stroke (stroke)
# );
#
#
# CREATE TABLE Heat (
#     id VARCHAR(10),
#     event_id VARCHAR(10),
#     meet_name VARCHAR(20),
#     PRIMARY KEY (id, event_id, meet_name),
#     FOREIGN KEY (event_id) REFERENCES Event (id),
#     FOREIGN KEY (meet_name) REFERENCES Meet (name)
# );
#
# CREATE TABLE Swim (
#     heat_id VARCHAR(10),
#     event_id VARCHAR(10),
#     meet_name VARCHAR(20),
#     participant_id VARCHAR(10),
#     leg INT NOT NULL,
#     --app side should add '.0' for integer input time
#     t DECIMAL,
#     PRIMARY KEY (heat_id, event_id, meet_name, participant_id),
#     FOREIGN KEY (heat_id, event_id, meet_name) REFERENCES Heat (id, event_id ,meet_name),
#     FOREIGN KEY (participant_id) REFERENCES Participant (id),
#     FOREIGN KEY (leg) REFERENCES Leg (leg),
#     CONSTRAINT chk_time CHECK (t > 0),
#     CONSTRAINT chk_gender
#     CHECK (checkSwimGender(event_id, participant_id)),
#     --for a relay race event, one school can have only one group in a heat
#     --(heat_id, event_id, meet_name, org_id of participant, leg) must be unique
#     CONSTRAINT chk_relay_school
#     CHECK (checkRelaySchool(heat_id, event_id, meet_name, participant_id, leg))
# );
# Out:
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO Org VALUES ('O001', 'Rice', TRUE),  ('O002', 'UTAustin', TRUE);
# INSERT INTO Meet VALUES ('RICE_2017', NULL, NULL, NULL);
# INSERT INTO Participant VALUES
#     ('P001', 'M', 'O001', 'Tom'),
#     ('P002', 'F', 'O001', 'Mary'),
#     ('P003', 'M', 'O001', 'Jim'),
#     ('P004', 'M', 'O002', 'Adam'),
#     ('P005', 'M', 'O002', 'Hack'),
#     ('P006', 'M', 'O002', 'Hack');
# INSERT INTO Leg VALUES (1), (2), (3), (4);
# INSERT INTO Stroke VALUES ('backstroke'), ('medley');
# INSERT INTO Distance VALUES (100), (200), (400);
# INSERT INTO Event VALUES ('E001', 'M', 100), ('E002', 'M', 100);
# INSERT INTO StrokeOf VALUES ('E001', 1, 'backstroke'),
#     ('E002', 1, 'medley'),
#     ('E002', 2, 'medley');
# INSERT INTO Heat VALUES ('1', 'E001', 'RICE_2017'),
#     ('1', 'E002', 'RICE_2017');
# Out:
# 2 rows affected.
# 1 rows affected.
# 6 rows affected.
# 4 rows affected.
# 2 rows affected.
# 3 rows affected.
# 2 rows affected.
# 3 rows affected.
# 2 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Swim;
# Out:
# 607 rows affected.
# [('1', 'E0107', 'NCAA_Summer', 'P411523', 1, Decimal('16.3748389')),
#  ('1', 'E0107', 'NCAA_Summer', 'P948241', 1, Decimal('16.40396974')),
#  ('1', 'E0107', 'NCAA_Summer', 'P664643', 1, Decimal('13.53774055')),
#  ('1', 'E0107', 'NCAA_Summer', 'P686315', 1, Decimal('12.41570303')),
#  ('1', 'E0107', 'NCAA_Summer', 'P944240', 1, Decimal('12.85323514')),
#  ('1', 'E0107', 'NCAA_Summer', 'P966483', 1, Decimal('11.85759413')),
#  ('1', 'E0107', 'NCAA_Summer', 'P852515', 1, Decimal('13.66983274')),
#  ('1', 'E0107', 'NCAA_Summer', 'P614836', 1, Decimal('13.16557278')),
#  ('1', 'E0107', 'NCAA_Summer', 'P581736', 1, Decimal('14.87364167')),
#  ('1', 'E0107', 'NCAA_Summer', 'P849004', 1, Decimal('16.08096591')),
#  ('1', 'E0107', 'NCAA_Summer', 'P913591', 1, Decimal('13.89281903')),
#  ('1', 'E0107', 'NCAA_Summer', 'P619446', 1, Decimal('13.33658822')),
#  ('1', 'E0107', 'NCAA_Summer', 'P158289', 1, Decimal('15.16944529')),
#  ('1', 'E0107', 'NCAA_Summer', 'P925991', 1, Decimal('12.07877553')),
#  ('1', 'E0107', 'NCAA_Summer', 'P132246', 1, Decimal('13.78668953')),
#  ('1', 'E0107', 'NCAA_Summer', 'P319962', 1, Decimal('15.93167917')),
#  ('1', 'E0107', 'NCAA_Summer', 'P364479', 1, Decimal('12.9350458')),
#  ('1', 'E0107', 'NCAA_Summer', 'P334035', 1, Decimal('14.15704974')),
#  ('1', 'E0107', 'NCAA_Summer', 'P879800', 1, Decimal('14.74922689')),
#  ('1', 'E0107', 'NCAA_Summer', 'P390796', 1, Decimal('12.0014812')),
#  ('3', 'E0107', 'NCAA_Summer', 'P419077', 1, Decimal('12.04906499')),
#  ('3', 'E0107', 'NCAA_Summer', 'P453891', 1, Decimal('13.77185263')),
#  ('3', 'E0107', 'NCAA_Summer', 'P552426', 1, Decimal('14.22006972')),
#  ('3', 'E0107', 'NCAA_Summer', 'P450947', 1, Decimal('15.12498059')),
#  ('3', 'E0107', 'NCAA_Summer', 'P358275', 1, Decimal('11.64234693')),
#  ('3', 'E0107', 'NCAA_Summer', 'P402065', 1, Decimal('15.03067709')),
#  ('3', 'E0107', 'NCAA_Summer', 'P484371', 1, Decimal('13.36662219')),
#  ('3', 'E0107', 'NCAA_Summer', 'P768448', 1, Decimal('13.2144709')),
#  ('3', 'E0107', 'NCAA_Summer', 'P744201', 1, Decimal('14.65523183')),
#  ('3', 'E0107', 'NCAA_Summer', 'P393193', 1, Decimal('15.51948156')),
#  ('3', 'E0107', 'NCAA_Summer', 'P198583', 1, Decimal('12.62829217')),
#  ('3', 'E0107', 'NCAA_Summer', 'P306538', 1, Decimal('16.89802727')),
#  ('3', 'E0107', 'NCAA_Summer', 'P722618', 1, Decimal('11.85598147')),
#  ('3', 'E0107', 'NCAA_Summer', 'P744651', 1, Decimal('14.29195673')),
#  ('3', 'E0107', 'NCAA_Summer', 'P772269', 1, Decimal('15.34075226')),
#  ('3', 'E0107', 'NCAA_Summer', 'P673060', 1, Decimal('17.99095688')),
#  ('3', 'E0107', 'NCAA_Summer', 'P315434', 1, Decimal('15.1812186')),
#  ('3', 'E0107', 'NCAA_Summer', 'P831119', 1, Decimal('12.37327832')),
#  ('3', 'E0107', 'NCAA_Summer', 'P595277', 1, Decimal('17.57399746')),
#  ('3', 'E0107', 'NCAA_Summer', 'P713611', 1, Decimal('16.29096987')),
#  ('3', 'E0107', 'NCAA_Summer', 'P313609', 1, Decimal('17.21586535')),
#  ('3', 'E0107', 'NCAA_Summer', 'P251935', 1, Decimal('13.11632395')),
#  ('3', 'E0107', 'NCAA_Summer', 'P844138', 1, Decimal('17.68036563')),
#  ('3', 'E0107', 'NCAA_Summer', 'P544348', 1, Decimal('14.38918012')),
#  ('3', 'E0107', 'NCAA_Summer', 'P643181', 1, Decimal('17.12245624')),
#  ('3', 'E0107', 'NCAA_Summer', 'P801697', 1, Decimal('12.06544583')),
#  ('3', 'E0107', 'NCAA_Summer', 'P282743', 1, Decimal('13.52452465')),
#  ('3', 'E0107', 'NCAA_Summer', 'P497862', 1, Decimal('17.83103051')),
#  ('3', 'E0107', 'NCAA_Summer', 'P503806', 1, Decimal('18.3687771')),
#  ('3', 'E0107', 'NCAA_Summer', 'P354503', 1, Decimal('14.03698192')),
#  ('3', 'E0107', 'NCAA_Summer', 'P126504', 1, Decimal('13.68146573')),
#  ('3', 'E0107', 'NCAA_Summer', 'P171587', 1, Decimal('11.70617453')),
#  ('3', 'E0107', 'NCAA_Summer', 'P102099', 1, Decimal('12.77938896')),
#  ('3', 'E0107', 'NCAA_Summer', 'P676479', 1, Decimal('16.48348075')),
#  ('3', 'E0107', 'NCAA_Summer', 'P717486', 1, Decimal('15.94297716')),
#  ('3', 'E0107', 'NCAA_Summer', 'P132685', 1, Decimal('11.86828583')),
#  ('3', 'E0107', 'NCAA_Summer', 'P834447', 1, Decimal('16.29509854')),
#  ('3', 'E0107', 'NCAA_Summer', 'P493853', 1, Decimal('12.9752733')),
#  ('3', 'E0107', 'NCAA_Summer', 'P214547', 1, Decimal('14.49850549')),
#  ('3', 'E0107', 'NCAA_Summer', 'P518763', 1, Decimal('12.12878686')),
#  ('3', 'E0107', 'NCAA_Summer', 'P266751', 1, Decimal('12.21837815')),
#  ('3', 'E0107', 'NCAA_Summer', 'P163990', 1, Decimal('14.84995278')),
#  ('3', 'E0107', 'NCAA_Summer', 'P562400', 1, Decimal('15.63315995')),
#  ('4', 'E0107', 'NCAA_Summer', 'P363719', 1, Decimal('18.28778595')),
#  ('4', 'E0107', 'NCAA_Summer', 'P478858', 1, Decimal('17.46121026')),
#  ('4', 'E0107', 'NCAA_Summer', 'P853409', 1, Decimal('12.52489882')),
#  ('4', 'E0107', 'NCAA_Summer', 'P298187', 1, Decimal('12.74124913')),
#  ('4', 'E0107', 'NCAA_Summer', 'P674970', 1, Decimal('13.95993742')),
#  ('4', 'E0107', 'NCAA_Summer', 'P307392', 1, Decimal('16.61100287')),
#  ('4', 'E0107', 'NCAA_Summer', 'P178934', 1, Decimal('16.13422424')),
#  ('4', 'E0107', 'NCAA_Summer', 'P814834', 1, Decimal('17.01328429')),
#  ('4', 'E0107', 'NCAA_Summer', 'P414627', 1, Decimal('11.96001619')),
#  ('4', 'E0107', 'NCAA_Summer', 'P334035', 1, Decimal('14.18824084')),
#  ('4', 'E0107', 'NCAA_Summer', 'P343775', 1, Decimal('16.85955895')),
#  ('4', 'E0107', 'NCAA_Summer', 'P774555', 1, Decimal('13.53054363')),
#  ('4', 'E0107', 'NCAA_Summer', 'P813991', 1, Decimal('16.78222465')),
#  ('4', 'E0107', 'NCAA_Summer', 'P446185', 1, Decimal('17.33782063')),
#  ('4', 'E0107', 'NCAA_Summer', 'P362851', 1, Decimal('16.82289323')),
#  ('4', 'E0107', 'NCAA_Summer', 'P720454', 1, Decimal('16.55663331')),
#  ('4', 'E0107', 'NCAA_Summer', 'P194002', 1, Decimal('15.70183794')),
#  ('4', 'E0107', 'NCAA_Summer', 'P420213', 1, Decimal('11.94360744')),
#  ('4', 'E0107', 'NCAA_Summer', 'P837450', 1, Decimal('13.02380132')),
#  ('4', 'E0107', 'NCAA_Summer', 'P868463', 1, Decimal('16.38907675')),
#  ('4', 'E0107', 'NCAA_Summer', 'P209774', 1, Decimal('15.31661125')),
#  ('4', 'E0107', 'NCAA_Summer', 'P948241', 1, Decimal('18.18587836')),
#  ('4', 'E0107', 'NCAA_Summer', 'P132246', 1, Decimal('16.53442993')),
#  ('4', 'E0107', 'NCAA_Summer', 'P581736', 1, Decimal('13.18581297')),
#  ('4', 'E0107', 'NCAA_Summer', 'P139417', 1, Decimal('13.46240041')),
#  ('4', 'E0107', 'NCAA_Summer', 'P855086', 1, Decimal('13.80138323')),
#  ('4', 'E0107', 'NCAA_Summer', 'P994822', 1, Decimal('16.94299984')),
#  ('4', 'E0107', 'NCAA_Summer', 'P482516', 1, Decimal('15.01749948')),
#  ('4', 'E0107', 'NCAA_Summer', 'P350887', 1, Decimal('13.83993914')),
#  ('4', 'E0107', 'NCAA_Summer', 'P123639', 1, Decimal('16.50993404')),
#  ('4', 'E0107', 'NCAA_Summer', 'P373735', 1, Decimal('17.30623055')),
#  ('4', 'E0107', 'NCAA_Summer', 'P216672', 1, Decimal('15.89148813')),
#  ('4', 'E0107', 'NCAA_Summer', 'P424921', 1, Decimal('13.89834756')),
#  ('4', 'E0107', 'NCAA_Summer', 'P801129', 1, Decimal('16.55176257')),
#  ('1', 'E0212', 'NCAA_Summer', 'P844138', 1, Decimal('16.50864067')),
#  ('1', 'E0212', 'NCAA_Summer', 'P395940', 1, Decimal('17.19703123')),
#  ('1', 'E0212', 'NCAA_Summer', 'P174047', 1, Decimal('11.55789')),
#  ('1', 'E0212', 'NCAA_Summer', 'P834447', 1, Decimal('13.31676473')),
#  ('1', 'E0212', 'NCAA_Summer', 'P888246', 1, Decimal('15.33125716')),
#  ('1', 'E0212', 'NCAA_Summer', 'P512304', 1, Decimal('12.41766544')),
#  ('1', 'E0212', 'NCAA_Summer', 'P686988', 1, Decimal('12.2234')),
#  ('1', 'E0212', 'NCAA_Summer', 'P477094', 1, Decimal('14.90350465')),
#  ('1', 'E0212', 'NCAA_Summer', 'P650269', 1, Decimal('13.55439857')),
#  ('1', 'E0212', 'NCAA_Summer', 'P132685', 1, Decimal('13.81837457')),
#  ('1', 'E0212', 'NCAA_Summer', 'P944182', 1, Decimal('13.17836356')),
#  ('1', 'E0212', 'NCAA_Summer', 'P263779', 1, Decimal('14.82261917')),
#  ('1', 'E0212', 'NCAA_Summer', 'P761841', 1, Decimal('12.78481811')),
#  ('1', 'E0212', 'NCAA_Summer', 'P266751', 1, Decimal('16.22098484')),
#  ('1', 'E0212', 'NCAA_Summer', 'P387891', 1, Decimal('12.83590553')),
#  ('1', 'E0212', 'NCAA_Summer', 'P187734', 1, Decimal('14.26662839')),
#  ('1', 'E0212', 'NCAA_Summer', 'P451746', 1, Decimal('14.17552066')),
#  ('1', 'E0212', 'NCAA_Summer', 'P962214', 1, Decimal('14.35385682')),
#  ('1', 'E0212', 'NCAA_Summer', 'P198583', 1, Decimal('13.05579963')),
#  ('1', 'E0212', 'NCAA_Summer', 'P419077', 1, Decimal('16.85917404')),
#  ('1', 'E0212', 'NCAA_Summer', 'P561028', 1, Decimal('14.80383614')),
#  ('1', 'E0212', 'NCAA_Summer', 'P514806', 1, Decimal('15.45435268')),
#  ('1', 'E0212', 'NCAA_Summer', 'P893682', 1, Decimal('15.45031006')),
#  ('1', 'E0212', 'NCAA_Summer', 'P744651', 1, Decimal('15.15582819')),
#  ('1', 'E0212', 'NCAA_Summer', 'P257391', 1, Decimal('15.05953456')),
#  ('2', 'E0212', 'NCAA_Summer', 'P951470', 1, Decimal('11.64423963')),
#  ('2', 'E0212', 'NCAA_Summer', 'P944182', 1, Decimal('12.50112519')),
#  ('2', 'E0212', 'NCAA_Summer', 'P393193', 1, Decimal('13.16208447')),
#  ('2', 'E0212', 'NCAA_Summer', 'P259364', 1, Decimal('9.65784')),
#  ('2', 'E0212', 'NCAA_Summer', 'P240255', 1, Decimal('9.876524517')),
#  ('2', 'E0212', 'NCAA_Summer', 'P102099', 1, Decimal('12.62401857')),
#  ('2', 'E0212', 'NCAA_Summer', 'P314927', 1, Decimal('11.42698006')),
#  ('2', 'E0212', 'NCAA_Summer', 'P831119', 1, Decimal('12.06361227')),
#  ('2', 'E0212', 'NCAA_Summer', 'P870590', 1, Decimal('14.04302873')),
#  ('2', 'E0212', 'NCAA_Summer', 'P187734', 1, Decimal('10.06488443')),
#  ('2', 'E0212', 'NCAA_Summer', 'P313609', 1, Decimal('10.3606922')),
#  ('2', 'E0212', 'NCAA_Summer', 'P214547', 1, Decimal('10.74569961')),
#  ('2', 'E0212', 'NCAA_Summer', 'P697891', 1, Decimal('14.79137261')),
#  ('2', 'E0212', 'NCAA_Summer', 'P354503', 1, Decimal('14.84280914')),
#  ('2', 'E0212', 'NCAA_Summer', 'P596208', 1, Decimal('11.39609975')),
#  ('2', 'E0212', 'NCAA_Summer', 'P250591', 1, Decimal('14.98760365')),
#  ('2', 'E0212', 'NCAA_Summer', 'P761841', 1, Decimal('14.06470172')),
#  ('2', 'E0212', 'NCAA_Summer', 'P251935', 1, Decimal('13.89443365')),
#  ('2', 'E0212', 'NCAA_Summer', 'P722188', 1, Decimal('13.78928537')),
#  ('2', 'E0212', 'NCAA_Summer', 'P408363', 1, Decimal('15.42063285')),
#  ('2', 'E0212', 'NCAA_Summer', 'P996063', 1, Decimal('13.21443475')),
#  ('2', 'E0212', 'NCAA_Summer', 'P545233', 1, Decimal('12.73675216')),
#  ('2', 'E0212', 'NCAA_Summer', 'P263690', 1, Decimal('12.22534474')),
#  ('2', 'E0212', 'NCAA_Summer', 'P673060', 1, Decimal('9.920128795')),
#  ('2', 'E0212', 'NCAA_Summer', 'P239302', 1, Decimal('11.86522163')),
#  ('2', 'E0212', 'NCAA_Summer', 'P305399', 1, Decimal('14.93087283')),
#  ('2', 'E0212', 'NCAA_Summer', 'P783509', 1, Decimal('15.18051824')),
#  ('2', 'E0212', 'NCAA_Summer', 'P552426', 1, Decimal('10.17624508')),
#  ('2', 'E0212', 'NCAA_Summer', 'P385867', 1, Decimal('10.42761111')),
#  ('2', 'E0212', 'NCAA_Summer', 'P893682', 1, Decimal('15.25571549')),
#  ('2', 'E0212', 'NCAA_Summer', 'P710107', 1, Decimal('10.56720163')),
#  ('3', 'E0212', 'NCAA_Summer', 'P216672', 1, Decimal('12.93454769')),
#  ('3', 'E0212', 'NCAA_Summer', 'P246719', 1, Decimal('13.13212094')),
#  ('3', 'E0212', 'NCAA_Summer', 'P420213', 1, Decimal('13.19887088')),
#  ('3', 'E0212', 'NCAA_Summer', 'P813991', 1, Decimal('11.55482064')),
#  ('3', 'E0212', 'NCAA_Summer', 'P411523', 1, Decimal('14.07321917')),
#  ('3', 'E0212', 'NCAA_Summer', 'P362851', 1, Decimal('11.05938083')),
#  ('3', 'E0212', 'NCAA_Summer', 'P281029', 1, Decimal('10.35813919')),
#  ('3', 'E0212', 'NCAA_Summer', 'P720454', 1, Decimal('10.91173197')),
#  ('3', 'E0212', 'NCAA_Summer', 'P194002', 1, Decimal('11.86747216')),
#  ('3', 'E0212', 'NCAA_Summer', 'P478858', 1, Decimal('12.87277164')),
#  ('3', 'E0212', 'NCAA_Summer', 'P472703', 1, Decimal('9.698855155')),
#  ('3', 'E0212', 'NCAA_Summer', 'P581736', 1, Decimal('10.14036131')),
#  ('3', 'E0212', 'NCAA_Summer', 'P334035', 1, Decimal('14.54220634')),
#  ('3', 'E0212', 'NCAA_Summer', 'P877604', 1, Decimal('11.0780158')),
#  ('3', 'E0212', 'NCAA_Summer', 'P946656', 1, Decimal('11.66506738')),
#  ('3', 'E0212', 'NCAA_Summer', 'P925991', 1, Decimal('12.81919994')),
#  ('3', 'E0212', 'NCAA_Summer', 'P944240', 1, Decimal('9.751429104')),
#  ('3', 'E0212', 'NCAA_Summer', 'P544338', 1, Decimal('14.79676062')),
#  ('3', 'E0212', 'NCAA_Summer', 'P919641', 1, Decimal('10.23174148')),
#  ('3', 'E0212', 'NCAA_Summer', 'P375195', 1, Decimal('14.41267227')),
#  ('3', 'E0212', 'NCAA_Summer', 'P691951', 1, Decimal('13.51138815')),
#  ('3', 'E0212', 'NCAA_Summer', 'P837450', 1, Decimal('14.26271601')),
#  ('3', 'E0212', 'NCAA_Summer', 'P993334', 1, Decimal('14.5045356')),
#  ('3', 'E0212', 'NCAA_Summer', 'P782093', 1, Decimal('13.06320008')),
#  ('3', 'E0212', 'NCAA_Summer', 'P998753', 1, Decimal('15.93672051')),
#  ('3', 'E0212', 'NCAA_Summer', 'P307392', 1, Decimal('13.12589725')),
#  ('3', 'E0212', 'NCAA_Summer', 'P333827', 1, Decimal('11.77896')),
#  ('3', 'E0212', 'NCAA_Summer', 'P109919', 1, Decimal('16.10024716')),
#  ('3', 'E0212', 'NCAA_Summer', 'P614836', 1, Decimal('12.56180197')),
#  ('3', 'E0212', 'NCAA_Summer', 'P627706', 1, Decimal('14.83557756')),
#  ('3', 'E0212', 'NCAA_Summer', 'P855086', 1, Decimal('13.83752956')),
#  ('3', 'E0212', 'NCAA_Summer', 'P891266', 1, Decimal('13.93884592')),
#  ('3', 'E0212', 'NCAA_Summer', 'P716897', 1, Decimal('16.32750494')),
#  ('3', 'E0212', 'NCAA_Summer', 'P363719', 1, Decimal('13.65719651')),
#  ('3', 'E0212', 'NCAA_Summer', 'P158289', 1, Decimal('16.19679941')),
#  ('3', 'E0212', 'NCAA_Summer', 'P132246', 1, Decimal('12.35364569')),
#  ('3', 'E0212', 'NCAA_Summer', 'P852515', 1, Decimal('12.44456371')),
#  ('3', 'E0212', 'NCAA_Summer', 'P529632', 1, Decimal('12.76123859')),
#  ('3', 'E0212', 'NCAA_Summer', 'P608878', 1, Decimal('15.5557161')),
#  ('3', 'E0212', 'NCAA_Summer', 'P667298', 1, Decimal('11.84862579')),
#  ('3', 'E0212', 'NCAA_Summer', 'P712128', 1, Decimal('15.76992214')),
#  ('1', 'E0307', 'SouthConfed', 'P246719', 1, Decimal('17.35208283')),
#  ('1', 'E0307', 'SouthConfed', 'P686315', 2, Decimal('16.67756591')),
#  ('1', 'E0307', 'SouthConfed', 'P581736', 3, Decimal('15.9768438')),
#  ('1', 'E0307', 'SouthConfed', 'P472703', 4, Decimal('14.80081601')),
#  ('1', 'E0307', 'SouthConfed', 'P320247', 1, Decimal('11.84758772')),
#  ('1', 'E0307', 'SouthConfed', 'P375195', 2, Decimal('16.12068625')),
#  ('1', 'E0307', 'SouthConfed', 'P350087', 3, Decimal('16.54280649')),
#  ('1', 'E0307', 'SouthConfed', 'P667298', 4, Decimal('12.39221068')),
#  ('1', 'E0307', 'SouthConfed', 'P946656', 1, Decimal('12.16235924')),
#  ('1', 'E0307', 'SouthConfed', 'P363719', 2, Decimal('13.16446824')),
#  ('1', 'E0307', 'SouthConfed', 'P326379', 3, Decimal('14.58001008')),
#  ('1', 'E0307', 'SouthConfed', 'P774555', 4, Decimal('16.1432543')),
#  ('1', 'E0307', 'SouthConfed', 'P411523', 1, Decimal('13.38451082')),
#  ('1', 'E0307', 'SouthConfed', 'P782093', 2, Decimal('12.62364375')),
#  ('1', 'E0307', 'SouthConfed', 'P414627', 3, Decimal('11.80007796')),
#  ('1', 'E0307', 'SouthConfed', 'P551881', 4, Decimal('12.98580404')),
#  ('1', 'E0307', 'SouthConfed', 'P608878', 1, Decimal('15.18511175')),
#  ('1', 'E0307', 'SouthConfed', 'P944240', 2, Decimal('13.64228411')),
#  ('1', 'E0307', 'SouthConfed', 'P482516', 3, Decimal('13.19878974')),
#  ('1', 'E0307', 'SouthConfed', 'P925991', 4, Decimal('14.84666623')),
#  ('1', 'E0407', 'Rice Invitational', 'P713611', 1, Decimal('10.55814666')),
#  ('1', 'E0407', 'Rice Invitational', 'P385867', 1, Decimal('11.15725046')),
#  ('1', 'E0407', 'Rice Invitational', 'P497862', 1, Decimal('11.59308396')),
#  ('1', 'E0407', 'Rice Invitational', 'P174047', 1, Decimal('12.11235199')),
#  ('1', 'E0407', 'Rice Invitational', 'P514806', 1, Decimal('15.23738918')),
#  ('1', 'E0407', 'Rice Invitational', 'P892923', 1, Decimal('12.92244561')),
#  ('1', 'E0407', 'Rice Invitational', 'P710107', 1, Decimal('12.55686017')),
#  ('1', 'E0407', 'Rice Invitational', 'P722188', 1, Decimal('12.44943194')),
#  ('1', 'E0407', 'Rice Invitational', 'P759847', 1, Decimal('10.68046412')),
#  ('1', 'E0407', 'Rice Invitational', 'P263779', 1, Decimal('14.39607282')),
#  ('1', 'E0407', 'Rice Invitational', 'P779068', 1, Decimal('10.94392356')),
#  ('1', 'E0407', 'Rice Invitational', 'P493853', 1, Decimal('14.9870769')),
#  ('1', 'E0407', 'Rice Invitational', 'P686988', 1, Decimal('13.43815358')),
#  ('1', 'E0407', 'Rice Invitational', 'P358275', 1, Decimal('11.77227176')),
#  ('1', 'E0407', 'Rice Invitational', 'P408363', 1, Decimal('9.948703242')),
#  ('1', 'E0407', 'Rice Invitational', 'P595277', 1, Decimal('12.50880031')),
#  ('1', 'E0407', 'Rice Invitational', 'P896372', 1, Decimal('10.26704278')),
#  ('1', 'E0407', 'Rice Invitational', 'P451746', 1, Decimal('13.73024104')),
#  ('1', 'E0407', 'Rice Invitational', 'P862621', 1, Decimal('11.95799701')),
#  ('1', 'E0407', 'Rice Invitational', 'P772269', 1, Decimal('16.69136585')),
#  ('1', 'E0407', 'Rice Invitational', 'P214547', 1, Decimal('10.38492953')),
#  ('1', 'E0407', 'Rice Invitational', 'P514607', 1, Decimal('13.96003846')),
#  ('1', 'E0407', 'Rice Invitational', 'P239302', 1, Decimal('11.72141218')),
#  ('1', 'E0407', 'Rice Invitational', 'P259364', 1, Decimal('13.0298189')),
#  ('1', 'E0407', 'Rice Invitational', 'P844138', 1, Decimal('11.38513487')),
#  ('1', 'E0407', 'Rice Invitational', 'P673060', 1, Decimal('14.92432718')),
#  ('1', 'E0407', 'Rice Invitational', 'P628983', 1, Decimal('12.46298261')),
#  ('1', 'E0407', 'Rice Invitational', 'P545233', 1, Decimal('10.64893677')),
#  ('1', 'E0407', 'Rice Invitational', 'P282743', 1, Decimal('11.82580861')),
#  ('1', 'E0407', 'Rice Invitational', 'P518763', 1, Decimal('9.762165551')),
#  ('1', 'E0407', 'Rice Invitational', 'P263690', 1, Decimal('11.29497175')),
#  ('1', 'E0407', 'Rice Invitational', 'P102099', 1, Decimal('14.72376084')),
#  ('1', 'E0407', 'Rice Invitational', 'P944182', 1, Decimal('13.10036623')),
#  ('1', 'E0407', 'Rice Invitational', 'P240255', 1, Decimal('13.27609644')),
#  ('1', 'E0407', 'Rice Invitational', 'P552426', 1, Decimal('14.39293897')),
#  ('1', 'E0407', 'Rice Invitational', 'P146456', 1, Decimal('13.74460098')),
#  ('1', 'E0407', 'Rice Invitational', 'P503886', 1, Decimal('12.81906809')),
#  ('1', 'E0407', 'Rice Invitational', 'P896191', 1, Decimal('15.26046973')),
#  ('1', 'E0407', 'Rice Invitational', 'P308956', 1, Decimal('13.33348968')),
#  ('1', 'E0407', 'Rice Invitational', 'P171587', 1, Decimal('11.91448512')),
#  ('1', 'E0407', 'Rice Invitational', 'P250591', 1, Decimal('12.25512843')),
#  ('1', 'E0407', 'Rice Invitational', 'P650269', 1, Decimal('11.9663631')),
#  ('1', 'E0407', 'Rice Invitational', 'P306538', 1, Decimal('11.55876')),
#  ('1', 'E0407', 'Rice Invitational', 'P975231', 1, Decimal('13.71372293')),
#  ('1', 'E0407', 'Rice Invitational', 'P198583', 1, Decimal('11.76712886')),
#  ('1', 'E0407', 'Rice Invitational', 'P944240', 1, Decimal('13.64191617')),
#  ('1', 'E0407', 'Rice Invitational', 'P868463', 1, Decimal('14.24840181')),
#  ('1', 'E0407', 'Rice Invitational', 'P848881', 1, Decimal('16.59114549')),
#  ('1', 'E0407', 'Rice Invitational', 'P350087', 1, Decimal('13.14128974')),
#  ('1', 'E0407', 'Rice Invitational', 'P571660', 1, Decimal('15.73033154')),
#  ('1', 'E0407', 'Rice Invitational', 'P948241', 1, Decimal('14.13212218')),
#  ('1', 'E0407', 'Rice Invitational', 'P490897', 1, Decimal('12.31412261')),
#  ('1', 'E0407', 'Rice Invitational', 'P390796', 1, Decimal('11.91683549')),
#  ('1', 'E0407', 'Rice Invitational', 'P712128', 1, Decimal('14.0143626')),
#  ('1', 'E0407', 'Rice Invitational', 'P298187', 1, Decimal('16.06072221')),
#  ('1', 'E0407', 'Rice Invitational', 'P551881', 1, Decimal('13.99450764')),
#  ('1', 'E0407', 'Rice Invitational', 'P478858', 1, Decimal('12.40507177')),
#  ('1', 'E0407', 'Rice Invitational', 'P375195', 1, Decimal('10.99078687')),
#  ('2', 'E0407', 'Rice Invitational', 'P420213', 1, Decimal('14.79610152')),
#  ('2', 'E0407', 'Rice Invitational', 'P472703', 1, Decimal('13.86374745')),
#  ('2', 'E0407', 'Rice Invitational', 'P691951', 1, Decimal('16.0207249')),
#  ('2', 'E0407', 'Rice Invitational', 'P877604', 1, Decimal('11.6356506')),
#  ('2', 'E0407', 'Rice Invitational', 'P891266', 1, Decimal('13.82668376')),
#  ('2', 'E0407', 'Rice Invitational', 'P209774', 1, Decimal('15.06595618')),
#  ('2', 'E0407', 'Rice Invitational', 'P139417', 1, Decimal('13.5279352')),
#  ('2', 'E0407', 'Rice Invitational', 'P581736', 1, Decimal('13.75451807')),
#  ('2', 'E0407', 'Rice Invitational', 'P690976', 1, Decimal('9.67777')),
#  ('2', 'E0407', 'Rice Invitational', 'P813991', 1, Decimal('12.75226494')),
#  ('2', 'E0407', 'Rice Invitational', 'P993334', 1, Decimal('13.23985719')),
#  ('2', 'E0407', 'Rice Invitational', 'P373735', 1, Decimal('13.81839454')),
#  ('2', 'E0407', 'Rice Invitational', 'P627706', 1, Decimal('15.41617078')),
#  ('2', 'E0407', 'Rice Invitational', 'P852515', 1, Decimal('14.89692257')),
#  ('2', 'E0407', 'Rice Invitational', 'P158289', 1, Decimal('14.48430624')),
#  ('2', 'E0407', 'Rice Invitational', 'P946656', 1, Decimal('12.70713114')),
#  ('2', 'E0407', 'Rice Invitational', 'P529632', 1, Decimal('14.58452123')),
#  ('2', 'E0407', 'Rice Invitational', 'P326379', 1, Decimal('16.44985509')),
#  ('2', 'E0407', 'Rice Invitational', 'P998753', 1, Decimal('10.41703143')),
#  ('2', 'E0407', 'Rice Invitational', 'P994822', 1, Decimal('16.21925734')),
#  ('2', 'E0407', 'Rice Invitational', 'P531550', 1, Decimal('13.58057398')),
#  ('2', 'E0407', 'Rice Invitational', 'P307392', 1, Decimal('12.12467382')),
#  ('2', 'E0407', 'Rice Invitational', 'P720454', 1, Decimal('10.83589183')),
#  ('2', 'E0407', 'Rice Invitational', 'P362851', 1, Decimal('12.20539547')),
# %%
# %%sql
# --same school
# INSERT INTO Swim VALUES
# ('1', 'E001', 'RICE_2017', 'P001', 1, NULL),
# ('1', 'E001', 'RICE_2017', 'P003', 2, NULL);
# Out:
# 2 rows affected.
# []

# %%
# %%sql
# --another  school
# INSERT INTO Swim VALUES
# ('1', 'E002', 'RICE_2017', 'P004', 1, NULL),
# ('1', 'E002', 'RICE_2017', 'P005', 1, NULL);
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#
# IntegrityError: new row for relation "swim" violates check constraint "chk_relay_school"
# DETAIL:  Failing row contains (1, E002, RICE_2017, P004, 1, null).
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-182-f46c514b416c> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "--another  school\nINSERT INTO Swim VALUES \n('1', 'E002', 'RICE_2017', 'P004', 1, NULL), \n('1', 'E002', 'RICE_2017', 'P005', 1, NULL);")
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# <decorator-gen-125> in execute(self, line, cell, local_ns)
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      78             return self._persist_dataframe(parsed['sql'], conn, user_ns)
#      79         try:
# ---> 80             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      81             return result
#      82         except (ProgrammingError, OperationalError) as e:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     270                 raise Exception("ipython_sql does not support transactions")
#     271             txt = sqlalchemy.sql.text(statement)
# --> 272             result = conn.session.execute(txt, user_namespace)
#     273             try:
#     274                 conn.session.execute('commit')
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     912                 type(object))
#     913         else:
# --> 914             return meth(self, multiparams, params)
#     915
#     916     def _execute_function(self, func, multiparams, params):
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     321
#     322     def _execute_on_connection(self, connection, multiparams, params):
# --> 323         return connection._execute_clauseelement(self, multiparams, params)
#     324
#     325     def unique_params(self, *optionaldict, **kwargs):
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1008             compiled_sql,
#    1009             distilled_params,
# -> 1010             compiled_sql, distilled_params
#    1011         )
#    1012         if self._has_events or self.engine._has_events:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1144                 parameters,
#    1145                 cursor,
# -> 1146                 context)
#    1147
#    1148         if self._has_events or self.engine._has_events:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1339                 util.raise_from_cause(
#    1340                     sqlalchemy_exception,
# -> 1341                     exc_info
#    1342                 )
#    1343             else:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     200     exc_type, exc_value, exc_tb = exc_info
#     201     cause = exc_value if exc_value is not exception else None
# --> 202     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     203
#     204 if py3k:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     183             value.__cause__ = cause
#     184         if value.__traceback__ is not tb:
# --> 185             raise value.with_traceback(tb)
#     186         raise value
#     187
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1137                         statement,
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#    1141             self._handle_dbapi_exception(
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     448
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#     452     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) new row for relation "swim" violates check constraint "chk_relay_school"
# DETAIL:  Failing row contains (1, E002, RICE_2017, P004, 1, null).
#  [SQL: "--another  school\nINSERT INTO Swim VALUES \n('1', 'E002', 'RICE_2017', 'P004', 1, NULL), \n('1', 'E002', 'RICE_2017', 'P005', 1, NULL);"]

# %%
# %%sql
# DROP FUNCTION IF EXISTS checkSwimGender(
#     event_id_value VARCHAR(10),
#     participant_id_value VARCHAR(10)) CASCADE;
# CREATE OR REPLACE FUNCTION checkSwimGender (
#     event_id_value VARCHAR(10),
#     participant_id_value VARCHAR(10))
# RETURNS BOOLEAN
# AS $$
#     DECLARE
#         event_gender VARCHAR(1);
#         participant_gender VARCHAR(1);
#     BEGIN
#         SELECT gender into event_gender From Event
#         WHERE id=event_id_value;
#         SELECT gender into participant_gender From Participant
#         WHERE id=participant_id_value;
#         IF event_gender!=participant_gender THEN
#             RETURN FALSE;
#         ELSE
#             RETURN TRUE;
#         END IF;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS checkRelaySchool(
#     heat_id_value VARCHAR(10),
#     event_id_value VARCHAR(10),
#     meet_name_value VARCHAR(20),
#     participant_id_value VARCHAR(10),
#     leg_value INT) CASCADE;
# CREATE OR REPLACE FUNCTION checkRelaySchool(
#     heat_id_value VARCHAR(10),
#     event_id_value VARCHAR(10),
#     meet_name_value VARCHAR(20),
#     participant_id_value VARCHAR(10),
#     leg_value INT)
# RETURNS BOOLEAN
# AS $$
#     DECLARE
#         event_leg_count INT;
#         count_schools INT;  --count of schools for each leg in a relay heat
#     BEGIN
#         SELECT COUNT(*) into event_leg_count
#         From StrokeOf
#         WHERE event_id=event_id_value;
#         IF event_leg_count > 1 THEN
#             SELECT Count(*) into count_schools
#             FROM Swim
#             INNER JOIN Participant ON Participant.id = Swim.participant_id
#             GROUP BY heat_id, event_id, meet_name, Participant.org_id, leg;
#             IF count_schools >= 1 THEN
#                 RETURN FALSE;
#             END IF;
#         END IF;
#         RETURN TRUE;
#     END $$
# LANGUAGE plpgsql
# STABLE;
# Out:
# Done.
# Done.
# []

# %%
# %%sql
#
# DO $$ BEGIN
#     PERFORM upsertSwim ('2', 'E1206', 'NCAA_Summer', 'P451875', 1, NULL);
# END $$;
#
# SELECT * FROM Swim;

# %%
# %%sql
# DROP FUNCTION IF EXISTS GetOrg(VARCHAR(10));
# CREATE OR REPLACE FUNCTION GetOrg (id_value VARCHAR(10))
# RETURNS TABLE (id VARCHAR(10), name VARCHAR(20), is_univ BOOLEAN)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Org WHERE Org.id = id_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetMeet (name_value VARCHAR(20));
# CREATE OR REPLACE FUNCTION GetMeet (name_value VARCHAR(20))
# RETURNS TABLE (name VARCHAR(20), start_date DATE, num_days INT, org_id VARCHAR(10))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Meet WHERE Meet.name = name_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetParticipant (id_value VARCHAR(10));
# CREATE OR REPLACE FUNCTION GetParticipant (id_value VARCHAR(10))
# RETURNS TABLE (id VARCHAR(10), gender VARCHAR(1), org_id VARCHAR(10), name VARCHAR(20))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Participant WHERE Participant.id = id_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetLeg (leg_value INT);
# CREATE OR REPLACE FUNCTION GetLeg (leg_value INT)
# RETURNS TABLE (leg INT)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Leg WHERE Leg.leg = leg_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetStroke (stroke_value VARCHAR(20));
# CREATE OR REPLACE FUNCTION GetStroke (stroke_value VARCHAR(20))
# RETURNS TABLE (stroke VARCHAR(20))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Stroke WHERE Stroke.stroke = stroke_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetDistance (distance_value INT);
# CREATE OR REPLACE FUNCTION GetDistance (distance_value INT)
# RETURNS TABLE (distance INT)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Distance WHERE Distance.distance = distance_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetEvent (id_value VARCHAR(10));
# CREATE OR REPLACE FUNCTION GetEvent (id_value VARCHAR(10))
# RETURNS TABLE (id VARCHAR(10), gender VARCHAR(1), distance INT)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Event WHERE Event.id = id_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetStrokeOf (event_id_value VARCHAR(10), leg_value INT);
# CREATE OR REPLACE FUNCTION GetStrokeOf (event_id_value VARCHAR(10), leg_value INT)
# RETURNS TABLE (event_id VARCHAR(10), leg INT, stroke VARCHAR(20))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM StrokeOf
#         WHERE StrokeOf.event_id = event_id_value AND StrokeOf.leg = leg_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
#
# DROP FUNCTION IF EXISTS GetHeat (id_value VARCHAR(10),
#                                     event_id_value VARCHAR(10), meet_name_value VARCHAR(20));
# CREATE OR REPLACE FUNCTION GetHeat (id_value VARCHAR(10),
#                                     event_id_value VARCHAR(10), meet_name_value VARCHAR(20))
# RETURNS TABLE (id VARCHAR(10), event_id VARCHAR(10), meet_name VARCHAR(20))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Heat WHERE Heat.id = id_value
#         AND Heat.event_id = event_id_value AND Heat.meet_name = meet_name_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
#
# DROP FUNCTION IF EXISTS GetSwim (heat_id_value VARCHAR(10),
#                                     event_id_value VARCHAR(10), meet_name_value VARCHAR(20),
#                                     participant_id_value VARCHAR(10));
#
# CREATE OR REPLACE FUNCTION GetSwim (heat_id_value VARCHAR(10),
#                                     event_id_value VARCHAR(10), meet_name_value VARCHAR(20),
#                                     participant_id_value VARCHAR(10))
# RETURNS TABLE (heat_id VARCHAR(10), event_id VARCHAR(10), meet_name VARCHAR(20), participant_id VARCHAR(10), leg INT, t DECIMAL)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Swim WHERE Swim.heat_id = heat_id_value
#         AND Swim.event_id = event_id_value AND Swim.meet_name = meet_name_value
#         AND Swim.participant_id = participant_id_value;
#     END $$
# LANGUAGE plpgsql
# STABLE;
# Out:
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# DROP FUNCTION IF EXISTS upsertOrg (
#     id_value VARCHAR(10),
#     name_value VARCHAR(20),
#     is_univ_value BOOLEAN);
# CREATE OR REPLACE FUNCTION upsertOrg (
#     id_value VARCHAR(10),
#     name_value VARCHAR(20),
#     is_univ_value BOOLEAN)
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Org
#         WHERE id=id_value;
#         IF matches=0 THEN
#             INSERT INTO Org VALUES
#             (id_value, name_value, is_univ_value);
#         ELSE
#             UPDATE Org SET
#             name=name_value, is_univ=is_univ_value
#             WHERE id=id_value;
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
# DROP FUNCTION IF EXISTS upsertMeet (
#     name_value VARCHAR(20),
#     start_date_value DATE,
#     num_days_value INT,
#     org_id_value VARCHAR(10));
# CREATE OR REPLACE FUNCTION upsertMeet (
#     name_value VARCHAR(20),
#     start_date_value DATE,
#     num_days_value INT,
#     org_id_value VARCHAR(10))
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Meet
#         WHERE name=name_value;
#         IF matches=0 THEN
#             INSERT INTO Meet VALUES
#             (name_value, start_date_value, num_days_value, org_id_value);
#         ELSE
#             UPDATE Meet SET
#             start_date=start_date_value,
#             num_days=num_days_value,
#             org_id=org_id_value
#             WHERE name=name_value;
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
#
#
# DROP FUNCTION IF EXISTS upsertParticipant (
#     id_value VARCHAR(10),
#     gender_value VARCHAR(1),
#     org_id_value VARCHAR(10),
#     name_value VARCHAR(20));
# CREATE OR REPLACE FUNCTION upsertParticipant (
#     id_value VARCHAR(10),
#     gender_value VARCHAR(1),
#     org_id_value VARCHAR(10),
#     name_value VARCHAR(20))
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Participant
#         WHERE id=id_value;
#         IF matches=0 THEN
#             INSERT INTO Participant VALUES
#             (id_value, gender_value, org_id_value, name_value);
#         ELSE
#             UPDATE Participant SET
#             gender=gender_value,
#             org_id=org_id_value,
#             name=name_value
#             WHERE id=id_value;
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
# DROP FUNCTION IF EXISTS upsertLeg (leg_value INT);
# CREATE OR REPLACE FUNCTION upsertLeg (leg_value INT)
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Leg
#         WHERE leg=leg_value;
#         IF matches=0 THEN
#             INSERT INTO Leg VALUES (leg_value);
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
# DROP FUNCTION IF EXISTS upsertStroke (stroke_value VARCHAR(20));
# CREATE OR REPLACE FUNCTION upsertStroke (stroke_value VARCHAR(20))
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Stroke
#         WHERE stroke=stroke_value;
#         IF matches=0 THEN
#             INSERT INTO Stroke VALUES (stroke_value);
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
# DROP FUNCTION IF EXISTS upsertDistance (distance_value INT);
# CREATE OR REPLACE FUNCTION upsertDistance (distance_value INT)
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Distance
#         WHERE distance=distance_value;
#         IF matches=0 THEN
#             INSERT INTO Distance VALUES (distance_value);
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
# DROP FUNCTION IF EXISTS upsertEvent (
#     id_value VARCHAR(10),
#     gender_value VARCHAR(1),
#     distance_value INT);
# CREATE OR REPLACE FUNCTION upsertEvent (
#     id_value VARCHAR(10),
#     gender_value VARCHAR(1),
#     distance_value INT)
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Event
#         WHERE id=id_value;
#         IF matches=0 THEN
#             INSERT INTO Event VALUES
#             (id_value, gender_value, distance_value);
#         ELSE
#             UPDATE Event SET
#             gender=gender_value,
#             distance=distance_value
#             WHERE id=id_value;
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
#
#
# DROP FUNCTION IF EXISTS upsertStrokeOf (
#     event_id_value VARCHAR(10),
#     leg_value INT,
#     stroke_value VARCHAR(20));
# CREATE OR REPLACE FUNCTION upsertStrokeOf (
#     event_id_value VARCHAR(10),
#     leg_value INT,
#     stroke_value VARCHAR(20))
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From StrokeOf
#         WHERE event_id=event_id_value
#         AND leg=leg_value;
#         IF matches=0 THEN
#             INSERT INTO StrokeOf VALUES
#             (event_id_value, leg_value, stroke_value);
#         ELSE
#             UPDATE StrokeOf SET
#             stroke=stroke_value
#             WHERE event_id=event_id_value
#             AND leg=leg_value;
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
#
# DROP FUNCTION IF EXISTS upsertHeat (
#     id_value VARCHAR(10),
#     event_id_value VARCHAR(10),
#     meet_name_value VARCHAR(20));
# CREATE OR REPLACE FUNCTION upsertHeat (
#     id_value VARCHAR(10),
#     event_id_value VARCHAR(10),
#     meet_name_value VARCHAR(20))
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Heat
#         WHERE id=id_value
#         AND event_id=event_id_value
#         AND meet_name=meet_name_value;
#         IF matches=0 THEN
#             INSERT INTO Heat VALUES
#             (id_value, event_id_value, meet_name_value);
#         END IF;
#     END $$
# LANGUAGE plpgsql;
#
#
#
#
# DROP FUNCTION IF EXISTS upsertSwim (
#     heat_id_value VARCHAR(10),
#     event_id_value VARCHAR(10),
#     meet_name_value VARCHAR(20),
#     participant_id_value VARCHAR(10),
#     leg_value INT,
#     t_value DECIMAL);
# CREATE OR REPLACE FUNCTION  upsertSwim (
#     heat_id_value VARCHAR(10),
#     event_id_value VARCHAR(10),
#     meet_name_value VARCHAR(20),
#     participant_id_value VARCHAR(10),
#     leg_value INT,
#     t_value DECIMAL)
# RETURNS VOID
# AS $$
#     DECLARE
#         matches INT;
#     BEGIN
#         SELECT COUNT(*) into matches From Swim
#         WHERE heat_id=heat_id_value
#         AND event_id=event_id_value
#         AND meet_name=meet_name_value
#         AND participant_id=participant_id_value;
#         IF matches=0 THEN
#             INSERT INTO Swim VALUES
#             (heat_id_value, event_id_value, meet_name_value,
#              participant_id_value, leg_value, t_value);
#         ELSE
#             UPDATE Swim SET
#             leg=leg_value,
#             t=t_value
#             WHERE heat_id=heat_id_value
#             AND event_id=event_id_value
#             AND meet_name=meet_name_value
#             AND participant_id=participant_id_value;
#         END IF;
#     END $$
# LANGUAGE plpgsql;
# Out:
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# DROP FUNCTION IF EXISTS GetAllOrg();
# CREATE OR REPLACE FUNCTION GetAllOrg ()
# RETURNS TABLE (id VARCHAR(10), name VARCHAR(20), is_univ BOOLEAN)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Org;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetAllMeet ();
# CREATE OR REPLACE FUNCTION GetAllMeet ()
# RETURNS TABLE (name VARCHAR(20), start_date DATE, num_days INT, org_id VARCHAR(10))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Meet;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetAllParticipant ();
# CREATE OR REPLACE FUNCTION GetAllParticipant ()
# RETURNS TABLE (id VARCHAR(10), gender VARCHAR(1), org_id VARCHAR(10), name VARCHAR(20))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Participant;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetAllLeg ();
# CREATE OR REPLACE FUNCTION GetAllLeg ()
# RETURNS TABLE (leg INT)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Leg;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetAllStroke ();
# CREATE OR REPLACE FUNCTION GetAllStroke ()
# RETURNS TABLE (stroke VARCHAR(20))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Stroke;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetAllDistance ();
# CREATE OR REPLACE FUNCTION GetAllDistance ()
# RETURNS TABLE (distance INT)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Distance;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetAllEvent ();
# CREATE OR REPLACE FUNCTION GetAllEvent ()
# RETURNS TABLE (id VARCHAR(10), gender VARCHAR(1), distance INT)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Event;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
# DROP FUNCTION IF EXISTS GetAllStrokeOf ();
# CREATE OR REPLACE FUNCTION GetAllStrokeOf ()
# RETURNS TABLE (event_id VARCHAR(10), leg INT, stroke VARCHAR(20))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM StrokeOf;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
#
# DROP FUNCTION IF EXISTS GetAllHeat ();
# CREATE OR REPLACE FUNCTION GetAllHeat ()
# RETURNS TABLE (id VARCHAR(10), event_id VARCHAR(10), meet_name VARCHAR(20))
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Heat;
#     END $$
# LANGUAGE plpgsql
# STABLE;
#
#
# DROP FUNCTION IF EXISTS GetAllSwim ();
# CREATE OR REPLACE FUNCTION GetAllSwim ()
# RETURNS TABLE (heat_id VARCHAR(10), event_id VARCHAR(10), meet_name VARCHAR(20), participant_id VARCHAR(10), leg INT, t DECIMAL)
# AS $$
#     BEGIN
#         RETURN QUERY SELECT * FROM Swim;
#     END $$
# LANGUAGE plpgsql
# STABLE;
# Out:
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# DO $$ BEGIN
#     PERFORM getAllOrg();
# END $$;
# Out:
# Done.
# []

# %%
# %%sql
# SELECT * FROM getAllSwim();
# Out:
# 607 rows affected.
# [('1', 'E0107', 'NCAA_Summer', 'P411523', 1, Decimal('16.3748389')),
#  ('1', 'E0107', 'NCAA_Summer', 'P948241', 1, Decimal('16.40396974')),
#  ('1', 'E0107', 'NCAA_Summer', 'P664643', 1, Decimal('13.53774055')),
#  ('1', 'E0107', 'NCAA_Summer', 'P686315', 1, Decimal('12.41570303')),
#  ('1', 'E0107', 'NCAA_Summer', 'P944240', 1, Decimal('12.85323514')),
#  ('1', 'E0107', 'NCAA_Summer', 'P966483', 1, Decimal('11.85759413')),
#  ('1', 'E0107', 'NCAA_Summer', 'P852515', 1, Decimal('13.66983274')),
#  ('1', 'E0107', 'NCAA_Summer', 'P614836', 1, Decimal('13.16557278')),
#  ('1', 'E0107', 'NCAA_Summer', 'P581736', 1, Decimal('14.87364167')),
#  ('1', 'E0107', 'NCAA_Summer', 'P849004', 1, Decimal('16.08096591')),
#  ('1', 'E0107', 'NCAA_Summer', 'P913591', 1, Decimal('13.89281903')),
#  ('2', 'E0107', 'NCAA_Summer', 'P925991', 1, Decimal('14.88796386')),
#  ('2', 'E0107', 'NCAA_Summer', 'P926423', 1, Decimal('16.5277275')),
#  ('2', 'E0107', 'NCAA_Summer', 'P139417', 1, Decimal('14.07580003')),
#  ('3', 'E0107', 'NCAA_Summer', 'P305399', 1, Decimal('16.68605254')),
#  ('3', 'E0107', 'NCAA_Summer', 'P296082', 1, Decimal('15.75410247')),
#  ('3', 'E0107', 'NCAA_Summer', 'P561028', 1, Decimal('12.54925464')),
#  ('3', 'E0107', 'NCAA_Summer', 'P779068', 1, Decimal('15.01077375')),
#  ('3', 'E0107', 'NCAA_Summer', 'P174047', 1, Decimal('14.53633902')),
#  ('3', 'E0107', 'NCAA_Summer', 'P962214', 1, Decimal('12.61267382')),
#  ('3', 'E0107', 'NCAA_Summer', 'P451746', 1, Decimal('16.62890189')),
#  ('3', 'E0107', 'NCAA_Summer', 'P419077', 1, Decimal('12.04906499')),
#  ('3', 'E0107', 'NCAA_Summer', 'P453891', 1, Decimal('13.77185263')),
#  ('3', 'E0107', 'NCAA_Summer', 'P552426', 1, Decimal('14.22006972')),
#  ('3', 'E0107', 'NCAA_Summer', 'P450947', 1, Decimal('15.12498059')),
#  ('3', 'E0107', 'NCAA_Summer', 'P358275', 1, Decimal('11.64234693')),
#  ('3', 'E0107', 'NCAA_Summer', 'P402065', 1, Decimal('15.03067709')),
#  ('3', 'E0107', 'NCAA_Summer', 'P484371', 1, Decimal('13.36662219')),
#  ('3', 'E0107', 'NCAA_Summer', 'P768448', 1, Decimal('13.2144709')),
#  ('3', 'E0107', 'NCAA_Summer', 'P744201', 1, Decimal('14.65523183')),
#  ('3', 'E0107', 'NCAA_Summer', 'P393193', 1, Decimal('15.51948156')),
#  ('3', 'E0107', 'NCAA_Summer', 'P198583', 1, Decimal('12.62829217')),
#  ('3', 'E0107', 'NCAA_Summer', 'P306538', 1, Decimal('16.89802727')),
#  ('3', 'E0107', 'NCAA_Summer', 'P722618', 1, Decimal('11.85598147')),
#  ('3', 'E0107', 'NCAA_Summer', 'P744651', 1, Decimal('14.29195673')),
#  ('3', 'E0107', 'NCAA_Summer', 'P772269', 1, Decimal('15.34075226')),
#  ('3', 'E0107', 'NCAA_Summer', 'P673060', 1, Decimal('17.99095688')),
#  ('3', 'E0107', 'NCAA_Summer', 'P315434', 1, Decimal('15.1812186')),
#  ('3', 'E0107', 'NCAA_Summer', 'P831119', 1, Decimal('12.37327832')),
#  ('3', 'E0107', 'NCAA_Summer', 'P595277', 1, Decimal('17.57399746')),
#  ('3', 'E0107', 'NCAA_Summer', 'P713611', 1, Decimal('16.29096987')),
#  ('3', 'E0107', 'NCAA_Summer', 'P313609', 1, Decimal('17.21586535')),
#  ('3', 'E0107', 'NCAA_Summer', 'P251935', 1, Decimal('13.11632395')),
#  ('3', 'E0107', 'NCAA_Summer', 'P844138', 1, Decimal('17.68036563')),
#  ('3', 'E0107', 'NCAA_Summer', 'P544348', 1, Decimal('14.38918012')),
#  ('3', 'E0107', 'NCAA_Summer', 'P643181', 1, Decimal('17.12245624')),
#  ('3', 'E0107', 'NCAA_Summer', 'P801697', 1, Decimal('12.06544583')),
#  ('3', 'E0107', 'NCAA_Summer', 'P282743', 1, Decimal('13.52452465')),
#  ('3', 'E0107', 'NCAA_Summer', 'P497862', 1, Decimal('17.83103051')),
#  ('3', 'E0107', 'NCAA_Summer', 'P503806', 1, Decimal('18.3687771')),
#  ('3', 'E0107', 'NCAA_Summer', 'P354503', 1, Decimal('14.03698192')),
#  ('3', 'E0107', 'NCAA_Summer', 'P126504', 1, Decimal('13.68146573')),
#  ('3', 'E0107', 'NCAA_Summer', 'P171587', 1, Decimal('11.70617453')),
#  ('3', 'E0107', 'NCAA_Summer', 'P102099', 1, Decimal('12.77938896')),
#  ('3', 'E0107', 'NCAA_Summer', 'P676479', 1, Decimal('16.48348075')),
#  ('3', 'E0107', 'NCAA_Summer', 'P717486', 1, Decimal('15.94297716')),
#  ('3', 'E0107', 'NCAA_Summer', 'P132685', 1, Decimal('11.86828583')),
#  ('3', 'E0107', 'NCAA_Summer', 'P834447', 1, Decimal('16.29509854')),
#  ('3', 'E0107', 'NCAA_Summer', 'P493853', 1, Decimal('12.9752733')),
#  ('3', 'E0107', 'NCAA_Summer', 'P214547', 1, Decimal('14.49850549')),
#  ('3', 'E0107', 'NCAA_Summer', 'P518763', 1, Decimal('12.12878686')),
#  ('3', 'E0107', 'NCAA_Summer', 'P266751', 1, Decimal('12.21837815')),
#  ('3', 'E0107', 'NCAA_Summer', 'P163990', 1, Decimal('14.84995278')),
#  ('3', 'E0107', 'NCAA_Summer', 'P562400', 1, Decimal('15.63315995')),
#  ('4', 'E0107', 'NCAA_Summer', 'P363719', 1, Decimal('18.28778595')),
#  ('4', 'E0107', 'NCAA_Summer', 'P478858', 1, Decimal('17.46121026')),
#  ('4', 'E0107', 'NCAA_Summer', 'P853409', 1, Decimal('12.52489882')),
#  ('4', 'E0107', 'NCAA_Summer', 'P298187', 1, Decimal('12.74124913')),
#  ('4', 'E0107', 'NCAA_Summer', 'P674970', 1, Decimal('13.95993742')),
#  ('4', 'E0107', 'NCAA_Summer', 'P307392', 1, Decimal('16.61100287')),
#  ('4', 'E0107', 'NCAA_Summer', 'P178934', 1, Decimal('16.13422424')),
#  ('4', 'E0107', 'NCAA_Summer', 'P814834', 1, Decimal('17.01328429')),
#  ('4', 'E0107', 'NCAA_Summer', 'P414627', 1, Decimal('11.96001619')),
#  ('4', 'E0107', 'NCAA_Summer', 'P334035', 1, Decimal('14.18824084')),
#  ('4', 'E0107', 'NCAA_Summer', 'P343775', 1, Decimal('16.85955895')),
#  ('4', 'E0107', 'NCAA_Summer', 'P774555', 1, Decimal('13.53054363')),
#  ('4', 'E0107', 'NCAA_Summer', 'P813991', 1, Decimal('16.78222465')),
#  ('4', 'E0107', 'NCAA_Summer', 'P446185', 1, Decimal('17.33782063')),
#  ('4', 'E0107', 'NCAA_Summer', 'P362851', 1, Decimal('16.82289323')),
#  ('4', 'E0107', 'NCAA_Summer', 'P720454', 1, Decimal('16.55663331')),
#  ('4', 'E0107', 'NCAA_Summer', 'P194002', 1, Decimal('15.70183794')),
#  ('4', 'E0107', 'NCAA_Summer', 'P420213', 1, Decimal('11.94360744')),
#  ('4', 'E0107', 'NCAA_Summer', 'P837450', 1, Decimal('13.02380132')),
#  ('4', 'E0107', 'NCAA_Summer', 'P868463', 1, Decimal('16.38907675')),
#  ('4', 'E0107', 'NCAA_Summer', 'P209774', 1, Decimal('15.31661125')),
#  ('4', 'E0107', 'NCAA_Summer', 'P948241', 1, Decimal('18.18587836')),
#  ('4', 'E0107', 'NCAA_Summer', 'P132246', 1, Decimal('16.53442993')),
#  ('4', 'E0107', 'NCAA_Summer', 'P581736', 1, Decimal('13.18581297')),
#  ('4', 'E0107', 'NCAA_Summer', 'P139417', 1, Decimal('13.46240041')),
#  ('4', 'E0107', 'NCAA_Summer', 'P855086', 1, Decimal('13.80138323')),
#  ('4', 'E0107', 'NCAA_Summer', 'P994822', 1, Decimal('16.94299984')),
#  ('4', 'E0107', 'NCAA_Summer', 'P482516', 1, Decimal('15.01749948')),
#  ('4', 'E0107', 'NCAA_Summer', 'P350887', 1, Decimal('13.83993914')),
#  ('4', 'E0107', 'NCAA_Summer', 'P123639', 1, Decimal('16.50993404')),
#  ('4', 'E0107', 'NCAA_Summer', 'P373735', 1, Decimal('17.30623055')),
#  ('4', 'E0107', 'NCAA_Summer', 'P216672', 1, Decimal('15.89148813')),
#  ('4', 'E0107', 'NCAA_Summer', 'P424921', 1, Decimal('13.89834756')),
#  ('4', 'E0107', 'NCAA_Summer', 'P801129', 1, Decimal('16.55176257')),
#  ('1', 'E0212', 'NCAA_Summer', 'P844138', 1, Decimal('16.50864067')),
#  ('1', 'E0212', 'NCAA_Summer', 'P395940', 1, Decimal('17.19703123')),
#  ('1', 'E0212', 'NCAA_Summer', 'P174047', 1, Decimal('11.55789')),
#  ('1', 'E0212', 'NCAA_Summer', 'P834447', 1, Decimal('13.31676473')),
#  ('1', 'E0212', 'NCAA_Summer', 'P888246', 1, Decimal('15.33125716')),
#  ('1', 'E0212', 'NCAA_Summer', 'P512304', 1, Decimal('12.41766544')),
#  ('1', 'E0212', 'NCAA_Summer', 'P686988', 1, Decimal('12.2234')),
#  ('1', 'E0212', 'NCAA_Summer', 'P477094', 1, Decimal('14.90350465')),
#  ('1', 'E0212', 'NCAA_Summer', 'P650269', 1, Decimal('13.55439857')),
#  ('1', 'E0212', 'NCAA_Summer', 'P132685', 1, Decimal('13.81837457')),
#  ('1', 'E0212', 'NCAA_Summer', 'P944182', 1, Decimal('13.17836356')),
#  ('1', 'E0212', 'NCAA_Summer', 'P263779', 1, Decimal('14.82261917')),
#  ('1', 'E0212', 'NCAA_Summer', 'P761841', 1, Decimal('12.78481811')),
#  ('1', 'E0212', 'NCAA_Summer', 'P266751', 1, Decimal('16.22098484')),
#  ('1', 'E0212', 'NCAA_Summer', 'P387891', 1, Decimal('12.83590553')),
#  ('1', 'E0212', 'NCAA_Summer', 'P187734', 1, Decimal('14.26662839')),
#  ('2', 'E0212', 'NCAA_Summer', 'P305399', 1, Decimal('14.93087283')),
#  ('2', 'E0212', 'NCAA_Summer', 'P783509', 1, Decimal('15.18051824')),
#  ('2', 'E0212', 'NCAA_Summer', 'P552426', 1, Decimal('10.17624508')),
#  ('2', 'E0212', 'NCAA_Summer', 'P385867', 1, Decimal('10.42761111')),
#  ('2', 'E0212', 'NCAA_Summer', 'P893682', 1, Decimal('15.25571549')),
#  ('2', 'E0212', 'NCAA_Summer', 'P710107', 1, Decimal('10.56720163')),
#  ('3', 'E0212', 'NCAA_Summer', 'P216672', 1, Decimal('12.93454769')),
#  ('3', 'E0212', 'NCAA_Summer', 'P246719', 1, Decimal('13.13212094')),
#  ('3', 'E0212', 'NCAA_Summer', 'P420213', 1, Decimal('13.19887088')),
#  ('3', 'E0212', 'NCAA_Summer', 'P813991', 1, Decimal('11.55482064')),
#  ('3', 'E0212', 'NCAA_Summer', 'P411523', 1, Decimal('14.07321917')),
#  ('3', 'E0212', 'NCAA_Summer', 'P362851', 1, Decimal('11.05938083')),
#  ('3', 'E0212', 'NCAA_Summer', 'P281029', 1, Decimal('10.35813919')),
#  ('3', 'E0212', 'NCAA_Summer', 'P720454', 1, Decimal('10.91173197')),
#  ('3', 'E0212', 'NCAA_Summer', 'P194002', 1, Decimal('11.86747216')),
#  ('3', 'E0212', 'NCAA_Summer', 'P478858', 1, Decimal('12.87277164')),
#  ('3', 'E0212', 'NCAA_Summer', 'P472703', 1, Decimal('9.698855155')),
#  ('3', 'E0212', 'NCAA_Summer', 'P581736', 1, Decimal('10.14036131')),
#  ('3', 'E0212', 'NCAA_Summer', 'P334035', 1, Decimal('14.54220634')),
#  ('3', 'E0212', 'NCAA_Summer', 'P877604', 1, Decimal('11.0780158')),
#  ('3', 'E0212', 'NCAA_Summer', 'P946656', 1, Decimal('11.66506738')),
#  ('3', 'E0212', 'NCAA_Summer', 'P925991', 1, Decimal('12.81919994')),
#  ('3', 'E0212', 'NCAA_Summer', 'P944240', 1, Decimal('9.751429104')),
#  ('3', 'E0212', 'NCAA_Summer', 'P544338', 1, Decimal('14.79676062')),
#  ('3', 'E0212', 'NCAA_Summer', 'P919641', 1, Decimal('10.23174148')),
#  ('3', 'E0212', 'NCAA_Summer', 'P375195', 1, Decimal('14.41267227')),
#  ('3', 'E0212', 'NCAA_Summer', 'P691951', 1, Decimal('13.51138815')),
#  ('3', 'E0212', 'NCAA_Summer', 'P837450', 1, Decimal('14.26271601')),
#  ('3', 'E0212', 'NCAA_Summer', 'P993334', 1, Decimal('14.5045356')),
#  ('3', 'E0212', 'NCAA_Summer', 'P782093', 1, Decimal('13.06320008')),
#  ('3', 'E0212', 'NCAA_Summer', 'P998753', 1, Decimal('15.93672051')),
#  ('3', 'E0212', 'NCAA_Summer', 'P307392', 1, Decimal('13.12589725')),
#  ('3', 'E0212', 'NCAA_Summer', 'P333827', 1, Decimal('11.77896')),
#  ('3', 'E0212', 'NCAA_Summer', 'P109919', 1, Decimal('16.10024716')),
#  ('3', 'E0212', 'NCAA_Summer', 'P614836', 1, Decimal('12.56180197')),
#  ('3', 'E0212', 'NCAA_Summer', 'P627706', 1, Decimal('14.83557756')),
#  ('3', 'E0212', 'NCAA_Summer', 'P855086', 1, Decimal('13.83752956')),
#  ('3', 'E0212', 'NCAA_Summer', 'P891266', 1, Decimal('13.93884592')),
#  ('3', 'E0212', 'NCAA_Summer', 'P716897', 1, Decimal('16.32750494')),
#  ('3', 'E0212', 'NCAA_Summer', 'P363719', 1, Decimal('13.65719651')),
#  ('3', 'E0212', 'NCAA_Summer', 'P158289', 1, Decimal('16.19679941')),
#  ('3', 'E0212', 'NCAA_Summer', 'P132246', 1, Decimal('12.35364569')),
#  ('3', 'E0212', 'NCAA_Summer', 'P852515', 1, Decimal('12.44456371')),
#  ('3', 'E0212', 'NCAA_Summer', 'P529632', 1, Decimal('12.76123859')),
#  ('3', 'E0212', 'NCAA_Summer', 'P608878', 1, Decimal('15.5557161')),
#  ('3', 'E0212', 'NCAA_Summer', 'P667298', 1, Decimal('11.84862579')),
#  ('3', 'E0212', 'NCAA_Summer', 'P712128', 1, Decimal('15.76992214')),
#  ('1', 'E0307', 'SouthConfed', 'P246719', 1, Decimal('17.35208283')),
#  ('1', 'E0307', 'SouthConfed', 'P686315', 2, Decimal('16.67756591')),
#  ('1', 'E0307', 'SouthConfed', 'P581736', 3, Decimal('15.9768438')),
#  ('1', 'E0307', 'SouthConfed', 'P472703', 4, Decimal('14.80081601')),
#  ('1', 'E0307', 'SouthConfed', 'P320247', 1, Decimal('11.84758772')),
#  ('1', 'E0307', 'SouthConfed', 'P375195', 2, Decimal('16.12068625')),
#  ('1', 'E0307', 'SouthConfed', 'P350087', 3, Decimal('16.54280649')),
#  ('1', 'E0307', 'SouthConfed', 'P667298', 4, Decimal('12.39221068')),
#  ('1', 'E0307', 'SouthConfed', 'P946656', 1, Decimal('12.16235924')),
#  ('1', 'E0307', 'SouthConfed', 'P363719', 2, Decimal('13.16446824')),
#  ('1', 'E0307', 'SouthConfed', 'P326379', 3, Decimal('14.58001008')),
#  ('1', 'E0307', 'SouthConfed', 'P774555', 4, Decimal('16.1432543')),
#  ('1', 'E0307', 'SouthConfed', 'P411523', 1, Decimal('13.38451082')),
#  ('1', 'E0307', 'SouthConfed', 'P782093', 2, Decimal('12.62364375')),
#  ('1', 'E0307', 'SouthConfed', 'P414627', 3, Decimal('11.80007796')),
#  ('1', 'E0307', 'SouthConfed', 'P551881', 4, Decimal('12.98580404')),
#  ('1', 'E0307', 'SouthConfed', 'P608878', 1, Decimal('15.18511175')),
#  ('1', 'E0307', 'SouthConfed', 'P944240', 2, Decimal('13.64228411')),
#  ('1', 'E0307', 'SouthConfed', 'P482516', 3, Decimal('13.19878974')),
#  ('1', 'E0307', 'SouthConfed', 'P925991', 4, Decimal('14.84666623')),
#  ('1', 'E0407', 'Rice Invitational', 'P713611', 1, Decimal('10.55814666')),
#  ('1', 'E0407', 'Rice Invitational', 'P385867', 1, Decimal('11.15725046')),
#  ('1', 'E0407', 'Rice Invitational', 'P497862', 1, Decimal('11.59308396')),
#  ('1', 'E0407', 'Rice Invitational', 'P174047', 1, Decimal('12.11235199')),
#  ('1', 'E0407', 'Rice Invitational', 'P514806', 1, Decimal('15.23738918')),
#  ('1', 'E0407', 'Rice Invitational', 'P892923', 1, Decimal('12.92244561')),
#  ('1', 'E0407', 'Rice Invitational', 'P710107', 1, Decimal('12.55686017')),
#  ('1', 'E0407', 'Rice Invitational', 'P722188', 1, Decimal('12.44943194')),
#  ('1', 'E0407', 'Rice Invitational', 'P759847', 1, Decimal('10.68046412')),
#  ('1', 'E0407', 'Rice Invitational', 'P263779', 1, Decimal('14.39607282')),
#  ('1', 'E0407', 'Rice Invitational', 'P779068', 1, Decimal('10.94392356')),
#  ('1', 'E0407', 'Rice Invitational', 'P493853', 1, Decimal('14.9870769')),
#  ('1', 'E0407', 'Rice Invitational', 'P686988', 1, Decimal('13.43815358')),
#  ('1', 'E0407', 'Rice Invitational', 'P358275', 1, Decimal('11.77227176')),
#  ('1', 'E0407', 'Rice Invitational', 'P408363', 1, Decimal('9.948703242')),
#  ('1', 'E0407', 'Rice Invitational', 'P595277', 1, Decimal('12.50880031')),
#  ('1', 'E0407', 'Rice Invitational', 'P896372', 1, Decimal('10.26704278')),
#  ('1', 'E0407', 'Rice Invitational', 'P451746', 1, Decimal('13.73024104')),
#  ('1', 'E0407', 'Rice Invitational', 'P862621', 1, Decimal('11.95799701')),
#  ('1', 'E0407', 'Rice Invitational', 'P772269', 1, Decimal('16.69136585')),
#  ('1', 'E0407', 'Rice Invitational', 'P214547', 1, Decimal('10.38492953')),
#  ('1', 'E0407', 'Rice Invitational', 'P514607', 1, Decimal('13.96003846')),
#  ('1', 'E0407', 'Rice Invitational', 'P239302', 1, Decimal('11.72141218')),
#  ('1', 'E0407', 'Rice Invitational', 'P259364', 1, Decimal('13.0298189')),
#  ('1', 'E0407', 'Rice Invitational', 'P844138', 1, Decimal('11.38513487')),
#  ('1', 'E0407', 'Rice Invitational', 'P673060', 1, Decimal('14.92432718')),
#  ('1', 'E0407', 'Rice Invitational', 'P628983', 1, Decimal('12.46298261')),
#  ('1', 'E0407', 'Rice Invitational', 'P545233', 1, Decimal('10.64893677')),
#  ('1', 'E0407', 'Rice Invitational', 'P282743', 1, Decimal('11.82580861')),
#  ('1', 'E0407', 'Rice Invitational', 'P518763', 1, Decimal('9.762165551')),
#  ('1', 'E0407', 'Rice Invitational', 'P263690', 1, Decimal('11.29497175')),
#  ('1', 'E0407', 'Rice Invitational', 'P102099', 1, Decimal('14.72376084')),
#  ('1', 'E0407', 'Rice Invitational', 'P944182', 1, Decimal('13.10036623')),
#  ('1', 'E0407', 'Rice Invitational', 'P240255', 1, Decimal('13.27609644')),
#  ('1', 'E0407', 'Rice Invitational', 'P552426', 1, Decimal('14.39293897')),
#  ('1', 'E0407', 'Rice Invitational', 'P146456', 1, Decimal('13.74460098')),
#  ('1', 'E0407', 'Rice Invitational', 'P503886', 1, Decimal('12.81906809')),
#  ('1', 'E0407', 'Rice Invitational', 'P896191', 1, Decimal('15.26046973')),
#  ('1', 'E0407', 'Rice Invitational', 'P308956', 1, Decimal('13.33348968')),
#  ('1', 'E0407', 'Rice Invitational', 'P171587', 1, Decimal('11.91448512')),
#  ('1', 'E0407', 'Rice Invitational', 'P250591', 1, Decimal('12.25512843')),
#  ('1', 'E0407', 'Rice Invitational', 'P650269', 1, Decimal('11.9663631')),
#  ('1', 'E0407', 'Rice Invitational', 'P306538', 1, Decimal('11.55876')),
#  ('1', 'E0407', 'Rice Invitational', 'P975231', 1, Decimal('13.71372293')),
#  ('1', 'E0407', 'Rice Invitational', 'P198583', 1, Decimal('11.76712886')),
#  ('1', 'E0407', 'Rice Invitational', 'P944240', 1, Decimal('13.64191617')),
#  ('1', 'E0407', 'Rice Invitational', 'P868463', 1, Decimal('14.24840181')),
#  ('1', 'E0407', 'Rice Invitational', 'P848881', 1, Decimal('16.59114549')),
#  ('1', 'E0407', 'Rice Invitational', 'P350087', 1, Decimal('13.14128974')),
#  ('1', 'E0407', 'Rice Invitational', 'P571660', 1, Decimal('15.73033154')),
#  ('1', 'E0407', 'Rice Invitational', 'P948241', 1, Decimal('14.13212218')),
#  ('1', 'E0407', 'Rice Invitational', 'P490897', 1, Decimal('12.31412261')),
#  ('1', 'E0407', 'Rice Invitational', 'P390796', 1, Decimal('11.91683549')),
#  ('1', 'E0407', 'Rice Invitational', 'P712128', 1, Decimal('14.0143626')),
#  ('1', 'E0407', 'Rice Invitational', 'P298187', 1, Decimal('16.06072221')),
#  ('1', 'E0407', 'Rice Invitational', 'P551881', 1, Decimal('13.99450764')),
#  ('1', 'E0407', 'Rice Invitational', 'P478858', 1, Decimal('12.40507177')),
#  ('1', 'E0407', 'Rice Invitational', 'P375195', 1, Decimal('10.99078687')),
#  ('2', 'E0407', 'Rice Invitational', 'P420213', 1, Decimal('14.79610152')),
#  ('2', 'E0407', 'Rice Invitational', 'P472703', 1, Decimal('13.86374745')),
#  ('2', 'E0407', 'Rice Invitational', 'P691951', 1, Decimal('16.0207249')),
#  ('2', 'E0407', 'Rice Invitational', 'P877604', 1, Decimal('11.6356506')),
#  ('2', 'E0407', 'Rice Invitational', 'P891266', 1, Decimal('13.82668376')),
#  ('2', 'E0407', 'Rice Invitational', 'P209774', 1, Decimal('15.06595618')),
#  ('2', 'E0407', 'Rice Invitational', 'P139417', 1, Decimal('13.5279352')),
#  ('2', 'E0407', 'Rice Invitational', 'P581736', 1, Decimal('13.75451807')),
#  ('2', 'E0407', 'Rice Invitational', 'P690976', 1, Decimal('9.67777')),
#  ('2', 'E0407', 'Rice Invitational', 'P813991', 1, Decimal('12.75226494')),
#  ('2', 'E0407', 'Rice Invitational', 'P993334', 1, Decimal('13.23985719')),
#  ('2', 'E0407', 'Rice Invitational', 'P373735', 1, Decimal('13.81839454')),
#  ('2', 'E0407', 'Rice Invitational', 'P627706', 1, Decimal('15.41617078')),
#  ('2', 'E0407', 'Rice Invitational', 'P852515', 1, Decimal('14.89692257')),
#  ('2', 'E1206', 'NCAA_Summer', 'P619446', 1, Decimal('12.02471907')),
#  ('2', 'E1206', 'NCAA_Summer', 'P837450', 1, Decimal('12.74052442')),
#  ('2', 'E1206', 'NCAA_Summer', 'P674970', 1, Decimal('14.84354777')),
#  ('2', 'E1206', 'NCAA_Summer', 'P244567', 1, Decimal('11.40775757')),
#  ('2', 'E1206', 'NCAA_Summer', 'P350087', 1, Decimal('12.5316226')),
#  ('2', 'E1206', 'NCAA_Summer', 'P294836', 1, Decimal('13.59818685')),
#  ('2', 'E1206', 'NCAA_Summer', 'P960306', 1, Decimal('10.56950603')),
#  ('2', 'E1206', 'NCAA_Summer', 'P139417', 1, Decimal('13.13940342')),
#  ('2', 'E1206', 'NCAA_Summer', 'P451875', 1, Decimal('10.42511681'))]

# %%
# %%sql
# DO $$ BEGIN
#     PERFORM GetOrg('U422');
# END $$;
# Out:
# Done.
# []

# %%
DROP FUNCTION IF EXISTS GetMeet (name_value VARCHAR(20));
CREATE OR REPLACE FUNCTION GetMeet (name_value VARCHAR(20))
RETURNS TABLE (name VARCHAR(20), start_date DATE, num_days INT, org_id VARCHAR(10))
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM Meet WHERE Meet.name = name_value;
    END $$
LANGUAGE plpgsql
STABLE;

DROP FUNCTION IF EXISTS GetParticipant (id_value VARCHAR(10));
CREATE OR REPLACE FUNCTION GetParticipant (id_value VARCHAR(10))
RETURNS TABLE (id VARCHAR(10), gender VARCHAR(1), org_id VARCHAR(10), name VARCHAR(20))
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM Participant WHERE Participant.id = id_value;
    END $$
LANGUAGE plpgsql
STABLE;

DROP FUNCTION IF EXISTS GetLeg (leg_value INT);
CREATE OR REPLACE FUNCTION GetLeg (leg_value INT)
RETURNS TABLE (leg INT)
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM Leg WHERE Leg.leg = leg_value;
    END $$
LANGUAGE plpgsql
STABLE;

DROP FUNCTION IF EXISTS GetStroke (stroke_value VARCHAR(20));
CREATE OR REPLACE FUNCTION GetStroke (stroke_value VARCHAR(20))
RETURNS TABLE (leg INT)
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM Stroke WHERE Stroke.stroke = stroke_value;
    END $$
LANGUAGE plpgsql
STABLE;

DROP FUNCTION IF EXISTS GetDistance (distance_value INT);
CREATE OR REPLACE FUNCTION GetDistance (distance_value INT)
RETURNS TABLE (leg INT)
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM Distance WHERE Distance.distance = distance_value;
    END $$
LANGUAGE plpgsql
STABLE;

DROP FUNCTION IF EXISTS GetEvent (id_value VARCHAR(10));
CREATE OR REPLACE FUNCTION GetEvent (id_value VARCHAR(10))
RETURNS TABLE (id VARCHAR(10), gender VARCHAR(1), distance INT)
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM Event WHERE Event.id = id_value;
    END $$
LANGUAGE plpgsql
STABLE;

DROP FUNCTION IF EXISTS GetStrokeOf (event_id_value VARCHAR(10), leg_value INT);
CREATE OR REPLACE FUNCTION GetStrokeOf (event_id_value VARCHAR(10), leg_value INT)
RETURNS TABLE (event_id VARCHAR(10), leg INT, stroke VARCHAR(20))
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM StrokeOf 
        WHERE StrokeOf.event_id = event_id_value AND StrokeOf.leg = leg_value;
    END $$
LANGUAGE plpgsql
STABLE;


DROP FUNCTION IF EXISTS GetHeat (id_value VARCHAR(10), 
                                    event_id_value VARCHAR(10), meet_name_value VARCHAR(20));
CREATE OR REPLACE FUNCTION GetHeat (id_value VARCHAR(10), 
                                    event_id_value VARCHAR(10), meet_name_value VARCHAR(20))
RETURNS TABLE (id VARCHAR(10), event_id VARCHAR(10), meet_name VARCHAR(20))
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM Heat WHERE Heat.id = id_value 
        AND Heat.event_id = event_id_value AND Heat.meet_name = meet_name_value;
    END $$
LANGUAGE plpgsql
STABLE;


DROP FUNCTION IF EXISTS GetSwim (heat_id_value VARCHAR(10), 
                                    event_id_value VARCHAR(10), meet_name_value VARCHAR(20),
                                    participant_id_value VARCHAR(10));

CREATE OR REPLACE FUNCTION GetSwim (heat_id_value VARCHAR(10), 
                                    event_id_value VARCHAR(10), meet_name_value VARCHAR(20),
                                    participant_id_value VARCHAR(10))
RETURNS TABLE (heat_id VARCHAR(10), event_id VARCHAR(10), meet_name VARCHAR(20), participant_id VARCHAR(10), leg INT, t DECIMAL)
AS $$
    BEGIN
        RETURN QUERY SELECT * FROM Swim WHERE Swim.heat_id = heat_id_value 
        AND Swim.event_id = event_id_value AND Swim.meet_name = meet_name_value
        AND Swim.participant_id = participant_id_value;
    END $$
LANGUAGE plpgsql
STABLE;

# %%
# %%sql
# DO $$ BEGIN
#     PERFORM upsertSwim ('2', 'E1206', 'NCAA_Summer', 'P451875', 1, NULL);
# END $$;
#
# SELECT * FROM Swim;
# Out:
# (psycopg2.ProgrammingError) function upsertswim(unknown, unknown, unknown, unknown, integer, unknown) is not unique
# LINE 1: SELECT upsertSwim ('2', 'E1206', 'NCAA_Summer', 'P451875', 1...
#                ^
# HINT:  Could not choose a best candidate function. You might need to add explicit type casts.
# QUERY:  SELECT upsertSwim ('2', 'E1206', 'NCAA_Summer', 'P451875', 1, NULL)
# CONTEXT:  PL/pgSQL function inline_code_block line 2 at PERFORM
#  [SQL: "DO $$ BEGIN\n    PERFORM upsertSwim ('2', 'E1206', 'NCAA_Summer', 'P451875', 1, NULL);\nEND $$;"]

# %%
# %%sql
# INSERT INTO Swim VALUES ('2', 'E1206', 'NCAA_Summer', 'P451875', 1, NULL);
# SELECT * FROM Swim;
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#
# IntegrityError: duplicate key value violates unique constraint "swim_pkey"
# DETAIL:  Key (heat_id, event_id, meet_name, participant_id)=(2, E1206, NCAA_Summer, P451875) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-36-23e207870229> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "INSERT INTO Swim VALUES ('2', 'E1206', 'NCAA_Summer', 'P451875', 1, NULL);\nSELECT * FROM Swim;")
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# <decorator-gen-125> in execute(self, line, cell, local_ns)
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      78             return self._persist_dataframe(parsed['sql'], conn, user_ns)
#      79         try:
# ---> 80             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      81             return result
#      82         except (ProgrammingError, OperationalError) as e:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     270                 raise Exception("ipython_sql does not support transactions")
#     271             txt = sqlalchemy.sql.text(statement)
# --> 272             result = conn.session.execute(txt, user_namespace)
#     273             try:
#     274                 conn.session.execute('commit')
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     912                 type(object))
#     913         else:
# --> 914             return meth(self, multiparams, params)
#     915
#     916     def _execute_function(self, func, multiparams, params):
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     321
#     322     def _execute_on_connection(self, connection, multiparams, params):
# --> 323         return connection._execute_clauseelement(self, multiparams, params)
#     324
#     325     def unique_params(self, *optionaldict, **kwargs):
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1008             compiled_sql,
#    1009             distilled_params,
# -> 1010             compiled_sql, distilled_params
#    1011         )
#    1012         if self._has_events or self.engine._has_events:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1144                 parameters,
#    1145                 cursor,
# -> 1146                 context)
#    1147
#    1148         if self._has_events or self.engine._has_events:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1339                 util.raise_from_cause(
#    1340                     sqlalchemy_exception,
# -> 1341                     exc_info
#    1342                 )
#    1343             else:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     200     exc_type, exc_value, exc_tb = exc_info
#     201     cause = exc_value if exc_value is not exception else None
# --> 202     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     203
#     204 if py3k:
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     183             value.__cause__ = cause
#     184         if value.__traceback__ is not tb:
# --> 185             raise value.with_traceback(tb)
#     186         raise value
#     187
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1137                         statement,
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#    1141             self._handle_dbapi_exception(
#
# C:\Users\Zilong\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     448
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#     452     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) duplicate key value violates unique constraint "swim_pkey"
# DETAIL:  Key (heat_id, event_id, meet_name, participant_id)=(2, E1206, NCAA_Summer, P451875) already exists.
#  [SQL: "INSERT INTO Swim VALUES ('2', 'E1206', 'NCAA_Summer', 'P451875', 1, NULL);"]

# %%
# %%sql
# UPDATE Swim SET leg=1, t=NULL
# WHERE heat_id='2' AND event_id='E1206'
# AND meet_name='NCAA_Summer'
# AND participant_id='P451875'
# ;
#
# SELECT * FROM Swim
# WHERE heat_id='2' AND event_id='E1206'
# AND meet_name='NCAA_Summer'
# AND participant_id='P451875'
# ;
# Out:
# 1 rows affected.
# 1 rows affected.
# [('2', 'E1206', 'NCAA_Summer', 'P451875', 1, None)]

# %%
# %%sql
#
# UPDATE Org SET name='', is_univ=False WHERE id='U422';
#
# SELECT * FROM Org
# WHERE id='U422';
# Out:
# 1 rows affected.
# 1 rows affected.
# [('U422', '', False)]

# %%
# %%sql
#
# DO $$ BEGIN
#     PERFORM upsertMeet ('Rice 2017', '2016-09-21', 4, 'O001');
# END $$;
#
# SELECT * FROM Meet;
# Out:
# Done.
# 1 rows affected.
# [('Rice 2017', datetime.date(2016, 9, 21), 4, 'O001')]

# %%
# %%sql
#
# DO $$ BEGIN
#     PERFORM upsertDistance (200);
# END $$;
#
# SELECT * FROM Participant ;
# Out:
# 1 rows affected.
# [('P001', 'M', 'O002', 'Mary')]

# %%
# %%sql
#
# DO $$ BEGIN
#     PERFORM upsertOrg ('O001', 'Rice_U', TRUE);
#     PERFORM upsertOrg ('O002', 'UTAustin', TRUE);
#     PERFORM upsertOrg ('O003', 'U_Houston', TRUE);
# END $$;
#
# SELECT * FROM Org;
# Out:
# Done.
# 3 rows affected.
# [('O001', 'Rice_U', True),
#  ('O002', 'UTAustin', True),
#  ('O003', 'U_Houston', True)]

# %%
# %%sql
#
# DO $$ BEGIN
#     PERFORM upsertOrg ('O008','', TRUE);
# END $$;
#
# SELECT * FROM Org;
# Out:
# Done.
# 10 rows affected.
# [('U422', 'UTAustin', True),
#  ('U502', 'UTDallas', True),
#  ('U430', 'RICE', True),
#  ('U693', 'Baylor', True),
#  ('U203', 'UoH', True),
#  ('U108', 'TAMU', True),
#  ('O931', 'NCAA', False),
#  ('O901', 'Woodlands', False),
#  ('O992', 'SouthTexas', False),
#  ('O008', '', True)]

# %%
# %%sql
# DROP FUNCTION IF EXISTS insertOrg (id_value VARCHAR(10), name_value VARCHAR(20), is_univ_value BOOLEAN);
# CREATE OR REPLACE FUNCTION insertOrg (id_value VARCHAR(10), name_value VARCHAR(20), is_univ_value BOOLEAN)
# RETURNS VOID
# AS $$
#     BEGIN
#         INSERT INTO Org (id, name, is_univ)
#             SELECT id_value, name_value, is_univ_value
#             WHERE NOT EXISTS (SELECT 1 FROM Org WHERE id=id_value);
#     END $$
# LANGUAGE plpgsql;
# Out:
# Done.
# Done.
# []

# %%
# %%sql
#
# SELECT * FROM GetOrg('O008');
# Out:
# 1 rows affected.
# [('O008', 'NULL', True)]

# %%
# %%sql
# SELECT * FROM Org;
# Out:
# 3 rows affected.
# [('O001', 'Rice_U', True),
#  ('O002', 'UTAustin', True),
#  ('O003', 'U_Houston', True)]

# %%
# %%sql
# UPDATE Org SET name='test', is_univ=False WHERE id='O123';
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Meet;
# Out:
# 5 rows affected.
# [('NCAA_Summer', datetime.date(2007, 5, 6), 4, 'O931'),
#  ('Rice Invitational', datetime.date(2007, 12, 10), 4, 'U430'),
#  ('UT_Meet', datetime.date(2007, 1, 7), 5, 'U422'),
#  ('SouthConfed', datetime.date(2006, 3, 11), 7, 'O992'),
#  ('Rice_Winter', datetime.date(2006, 5, 12), 4, 'U430')]

# %%
# %%sql
# --individual event ids
# DROP VIEW IF EXISTS individual_events;
# CREATE VIEW individual_events AS
# SELECT event_id
#         From StrokeOf
#         GROUP BY event_id
#         HAVING Count(*) = 1;
# SELECT * FROM individual_events;
# Out:
# Done.
# Done.
# 15 rows affected.
# [('E9301',),
#  ('E0218',),
#  ('E0107',),
#  ('E1007',),
#  ('E1206',),
#  ('E1144',),
#  ('E4133',),
#  ('E0507',),
#  ('E0407',),
#  ('E1302',),
#  ('E4142',),
#  ('E2301',),
#  ('E7311',),
#  ('E0212',),
#  ('E5550',)]

# %%
# %%sql
# --relay event ids
# DROP VIEW IF EXISTS relay_events;
# CREATE VIEW relay_events AS
# SELECT event_id
#         From StrokeOf
#         GROUP BY event_id
#         HAVING Count(*) > 1;
# SELECT * FROM relay_events;
# Out:
# Done.
# Done.
# 3 rows affected.
# [('E0422',), ('E0307',), ('E1107',)]

# %%
# %%sql
# DROP VIEW IF EXISTS meet_individual_info;
# CREATE VIEW meet_individual_info AS
# SELECT sw.meet_name,
#     sw.event_id,
#     e.gender AS gender, e.distance AS distance, s.stroke AS stroke,
#     sw.heat_id,
#     Org.id AS org_id, Org.name AS school,
#     sw.participant_id, p.name AS swimmer_name,
#     t,
#     RANK() OVER
#     (PARTITION BY sw.meet_name, sw.event_id, sw.participant_id ORDER BY sw.t ASC)
#     AS personal_rank,
#     --only choose the best time of a participant in an event
#     CASE WHEN ( RANK() OVER
#     (PARTITION BY sw.meet_name, sw.event_id, sw.participant_id ORDER BY sw.t ASC))=1
#     THEN RANK() OVER
#     (PARTITION BY sw.meet_name, sw.event_id ORDER BY sw.t ASC)
#     END AS event_rank
# FROM Swim sw
# INNER JOIN individual_events ind
#     ON ind.event_id = sw.event_id
# INNER JOIN Event e
#     ON sw.event_id = e.id
# INNER JOIN StrokeOf s
#     ON s.event_id = e.id AND s.leg=sw.leg
# INNER JOIN Participant p
#     ON p.id = sw.participant_id
# INNER JOIN Org
#     ON p.org_id = Org.id
# ORDER BY sw.meet_name, sw.event_id,
#     sw.heat_id,
#     event_rank,
#     school ASC
# ;
#
#
# SELECT * FROM meet_individual_info
# ;
# Out:
# Done.
# Done.
# 551 rows affected.
# [('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P544338', 'William', Decimal('11.6987'), 1, 4),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P891266', 'Robert', Decimal('11.74815471'), 1, 6),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P451875', 'Elijah', Decimal('11.77619264'), 1, 7),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P966483', 'Aiden', Decimal('11.85759413'), 1, 10),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P390796', 'Lucas', Decimal('12.0014812'), 1, 15),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P925991', 'Samuel', Decimal('12.07877553'), 1, 18),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P686315', 'Noah', Decimal('12.41570303'), 1, 25),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P326379', 'Carter', Decimal('12.7967373'), 1, 35),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P944240', 'Jackson', Decimal('12.85323514'), 1, 37),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P364479', 'William', Decimal('12.9350458'), 1, 38),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P619446', 'Lai', Decimal('13.33658822'), 1, 49),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P350887', 'Noah', Decimal('13.35034408'), 1, 50),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P664643', 'John', Decimal('13.53774055'), 1, 57),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P852515', 'Jacob', Decimal('13.66983274'), 1, 59),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P132246', 'Armaan', Decimal('13.78668953'), 1, 62),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P913591', 'Joseph', Decimal('13.89281903'), 1, 67),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P334035', 'David', Decimal('14.15704974'), 1, 74),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P960306', 'Samuel', Decimal('14.36935546'), 1, 80),
#  ('NCAA_Summer', 'E0107', 'M', 100, 'Freestyle', '1', 'U422', 'UTAustin', '

#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P314927', 'Karen', Decimal('11.42698006'), 1, 22),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U430', 'RICE', 'P951470', 'Sarah', Decimal('11.64423963'), 1, 25),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U502', 'UTDallas', 'P126715', 'Rebecca', Decimal('11.73986518'), 1, 27),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U693', 'Baylor', 'P198583', 'Natalie', Decimal('11.84730055'), 1, 29),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U430', 'RICE', 'P239302', 'Patricia', Decimal('11.86522163'), 1, 31),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U693', 'Baylor', 'P831119', 'Xi', Decimal('12.06361227'), 1, 33),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U430', 'RICE', 'P263690', 'Gina', Decimal('12.22534474'), 1, 35),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U203', 'UoH', 'P493853', 'Terry', Decimal('12.42516619'), 1, 39),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U430', 'RICE', 'P944182', 'Abril', Decimal('12.50112519'), 1, 42),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U693', 'Baylor', 'P102099', 'Rose', Decimal('12.62401857'), 1, 44),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P545233', 'Carolyn', Decimal('12.73675216'), 1, 46),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U693', 'Baylor', 'P393193', 'Charline', Decimal('13.16208447'), 1, 59),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U203', 'UoH', 'P996063', 'Stephanie', Decimal('13.21443475'), 1, 62),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P500771', 'Kavya', Decimal('13.39602667'), 1, 65),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U693', 'Baylor', 'P722188', 'Irma', Decimal('13.78928537'), 1, 72),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U203', 'UoH', 'P251935', 'Frances', Decimal('13.89443365'), 1, 75),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U430', 'RICE', 'P862621', 'Mia', Decimal('14.49461789'), 1, 87),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U203', 'UoH', 'P263779', 'Catheine', Decimal('14.59758848'), 1, 91),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P697891', 'Xu', Decimal('14.79137261'), 1, 93),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U693', 'Baylor', 'P354503', 'Patricia', Decimal('14.84280914'), 1, 98),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P305399', 'Marian', Decimal('14.93087283'), 1, 100),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U502', 'UTDallas', 'P250591', 'Chrn', Decimal('14.98760365'), 1, 101),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U693', 'Baylor', 'P783509', 'Jessica', Decimal('15.18051824'), 1, 104),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U693', 'Baylor', 'P893682', 'Xilin', Decimal('15.25571549'), 1, 106),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P408363', 'Sandra', Decimal('15.42063285'), 1, 109),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U203', 'UoH', 'P870590', 'Biyu', Decimal('14.04302873'), 2, None),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U203', 'UoH', 'P643181', 'Amanda', Decimal('15.33703491'), 2, None),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '2', 'U502', 'UTDallas', 'P761841', 'Valeria', Decimal('14.06470172'), 2, None),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P472703', 'Alejandro', Decimal('9.698855155'), 1, 2),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P944240', 'Jackson', Decimal('9.751429104'), 1, 3),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P581736', 'Aiden', Decimal('10.14036131'), 1, 7),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P919641', 'Thomas', Decimal('10.23174148'), 1, 9),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P281029', 'Michael', Decimal('10.35813919'), 1, 12),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P720454', 'Matias', Decimal('10.91173197'), 1, 17),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P362851', 'Carolyn', Decimal('11.05938083'), 1, 18),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P877604', 'David', Decimal('11.0780158'), 1, 19),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P813991', 'Daniel', Decimal('11.55482064'), 1, 23),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P946656', 'Caden', Decimal('11.66506738'), 1, 26),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P333827', 'John', Decimal('11.77896'), 1, 28),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P667298', 'Martin', Decimal('11.84862579'), 1, 30),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P194002', 'Suraj', Decimal('11.86747216'), 1, 32),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P132246', 'Armaan', Decimal('12.35364569'), 1, 36),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P852515', 'Jacob', Decimal('12.44456371'), 1, 40),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P614836', 'Benjamin', Decimal('12.56180197'), 1, 43),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P529632', 'Joseph', Decimal('12.76123859'), 1, 47),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P925991', 'Samuel', Decimal('12.81919994'), 1, 49),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P478858', 'Neil', Decimal('12.87277164'), 1, 51),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P216672', 'Jimmy', Decimal('12.93454769'), 1, 52),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U502', 'UTDallas', 'P782093', 'Diego', Decimal('13.06320008'), 1, 55),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P307392', 'Michael', Decimal('13.12589725'), 1, 56),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P246719', 'Liam', Decimal('13.13212094'), 1, 57),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P420213', 'Augustin', Decimal('13.19887088'), 1, 61),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P691951', 'Mohammad', Decimal('13.51138815'), 1, 66),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P363719', 'Ethan', Decimal('13.65719651'), 1, 68),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P855086', 'Jeremy', Decimal('13.83752956'), 1, 74),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P891266', 'Robert', Decimal('13.93884592'), 1, 77),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U502', 'UTDallas', 'P411523', 'Santiago', Decimal('14.07321917'), 1, 80),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P837450', 'Liam', Decimal('14.26271601'), 1, 83),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P375195', 'Benjamin', Decimal('14.41267227'), 1, 86),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P993334', 'Lucky', Decimal('14.5045356'), 1, 89),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P334035', 'David', Decimal('14.54220634'), 1, 90),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P544338', 'William', Decimal('14.79676062'), 1, 94),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P627706', 'Aiden', Decimal('14.83557756'), 1, 97),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P608878', 'Lucas', Decimal('15.5557161'), 1, 112),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P712128', 'Ryan', Decimal('15.76992214'), 1, 114),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U430', 'RICE', 'P998753', 'Aryan', Decimal('15.93672051'), 1, 117),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U693', 'Baylor', 'P109919', 'Daven', Decimal('16.10024716'), 1, 119),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P158289', 'Edward', Decimal('16.19679941'), 1, 120),
#  ('NCAA_Summer', 'E0212', 'M', 200, 'Medley', '3', 'U203', 'UoH', 'P716897', 'Alexander', Decimal('16.32750494'), 1, 122),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P503886', 'Chaya', Decimal('12.85445561'), 1, 1),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P393193', 'Charline', Decimal('12.92320517'), 1, 2),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P844138', 'Karen', Decimal('13.11523755'), 1, 3),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P776309', 'Maxine', Decimal('13.18262387'), 1, 4),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P126715', 'Rebecca', Decimal('13.3534012'), 1, 5),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P308956', 'Stephanie', Decimal('13.5318357'), 1, 6),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P514806', 'Elizabeth', Decimal('13.66351136'), 1, 7),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P257391', 'Amanda', Decimal('13.83855238'), 1, 8),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P834447', 'Pamela', Decimal('13.97600229'), 1, 9),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P174047', 'Margaret', Decimal('14.17246815'), 1, 10),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P686988', 'Debra', Decimal('14.27119624'), 1, 11),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P779068', 'Barbara', Decimal('14.34946009'), 1, 12),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P419077', 'Serena', Decimal('14.47646258'), 1, 13),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P561028', 'Xian', Decimal('14.5793366'), 1, 14),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P596208', 'Jennifer', Decimal('14.62144151'), 1, 15),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P422145', 'Rose', Decimal('14.68704108'), 1, 16),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P263690', 'Gina', Decimal('14.84281111'), 1, 17),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P870590', 'Biyu', Decimal('15.03067638'), 1, 18),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P650269', 'Gloria', Decimal('15.17222658'), 1, 19),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P938149', 'Aditi', Decimal('15.23706728'), 1, 20),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P402065', 'Lindsay', Decimal('15.41220824'), 1, 21),
#  ('NCAA_Summer', 'E1007', 'F', 100, 'Backstroke', '1', 'U502', 'UTDallas', '

#  ('Rice Invitational', 'E0407', 'F', 200, 'Butterfly', '2', 'U203', 'UoH', 'P420213', 'Augustin', Decimal('14.79610152'), 1, 71),
#  ('Rice Invitational', 'E0407', 'F', 200, 'Butterfly', '2', 'U430', 'RICE', 'P852515', 'Jacob', Decimal('14.89692257'), 1, 72),
#  ('Rice Invitational', 'E0407', 'F', 200, 'Butterfly', '2', 'U430', 'RICE', 'P209774', 'Nicky', Decimal('15.06595618'), 1, 75),
#  ('Rice Invitational', 'E0407', 'F', 200, 'Butterfly', '2', 'U203', 'UoH', 'P627706', 'Aiden', Decimal('15.41617078'), 1, 78),
#  ('Rice Invitational', 'E0407', 'F', 200, 'Butterfly', '2', 'U203', 'UoH', 'P674970', 'Santiago', Decimal('15.47295531'), 1, 79),
#  ('Rice Invitational', 'E0407', 'F', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P691951', 'Mohammad', Decimal('16.0207249'), 1, 81),
#  ('Rice Invitational', 'E0407', 'F', 200, 'Butterfly', '2', 'U430', 'RICE', 'P994822', 'Jeremiah', Decimal('16.21925734'), 1, 83),
#  ('Rice Invitational', 'E0407', 'F', 200, 'Butterfly', '2', 'U430', 'RICE', 'P326379', 'Carter', Decimal('16.44985509'), 1, 84),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P716897', 'Alexander', Decimal('8.55664'), 1, 1),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P855086', 'Jeremy', Decimal('8.72670957'), 1, 2),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P948241', 'Ishaan', Decimal('9.913818735'), 1, 3),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P674970', 'Santiago', Decimal('10.02622198'), 1, 4),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P132246', 'Armaan', Decimal('10.19318808'), 1, 5),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U502', 'UTDallas', 'P782093', 'Diego', Decimal('10.33761337'), 1, 6),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P877604', 'David', Decimal('10.37473962'), 1, 7),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P857171', 'Sebastian', Decimal('10.51895685'), 1, 8),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P891266', 'Robert', Decimal('10.55896'), 1, 9),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P390796', 'Lucas', Decimal('10.5818538'), 1, 10),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U502', 'UTDallas', 'P123639', 'Matt', Decimal('10.86560359'), 1, 11),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P868463', 'Christopher', Decimal('11.04760656'), 1, 12),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P852515', 'Jacob', Decimal('11.05454443'), 1, 13),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P333827', 'John', Decimal('11.09639014'), 1, 14),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P334035', 'David', Decimal('11.26560294'), 1, 15),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P362851', 'Carolyn', Decimal('11.30810713'), 1, 16),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U422', 'UTAustin', 'P913591', 'Joseph', Decimal('11.40811153'), 1, 17),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P373735', 'Logan', Decimal('11.43105936'), 1, 18),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P420213', 'Augustin', Decimal('11.54731162'), 1, 19),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U502', 'UTDallas', 'P414627', 'Mason', Decimal('11.64008347'), 1, 20),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P837450', 'Liam', Decimal('11.8292125'), 1, 21),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P363719', 'Ethan', Decimal('11.96533437'), 1, 22),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U422', 'UTAustin', 'P667298', 'Martin', Decimal('12.28850132'), 1, 23),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P993334', 'Lucky', Decimal('12.44405892'), 1, 24),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P114140', 'Nikhil', Decimal('12.79068518'), 1, 25),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P178934', 'James', Decimal('12.81518162'), 1, 26),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P720454', 'Matias', Decimal('12.91664634'), 1, 27),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U422', 'UTAustin', 'P350087', 'Nicolas', Decimal('13.65514532'), 1, 28),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U422', 'UTAustin', 'P691951', 'Mohammad', Decimal('13.9341367'), 1, 29),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U422', 'UTAustin', 'P849004', 'Jason', Decimal('14.07694154'), 1, 30),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P608878', 'Lucas', Decimal('14.2545089'), 1, 31),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P158289', 'Edward', Decimal('14.40922705'), 1, 32),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P853409', 'George', Decimal('14.529744'), 1, 33),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P946656', 'Caden', Decimal('14.83859993'), 1, 34),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U502', 'UTDallas', 'P551881', 'Ethan', Decimal('15.01272479'), 1, 35),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P482516', 'Jacob', Decimal('15.06363258'), 1, 36),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P926423', 'Deven', Decimal('15.23447833'), 1, 37),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U203', 'UoH', 'P627706', 'Aiden', Decimal('15.87718891'), 1, 38),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P960306', 'Samuel', Decimal('15.90519955'), 1, 39),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U430', 'RICE', 'P774555', 'Muhammad', Decimal('16.25493603'), 1, 40),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U693', 'Baylor', 'P664643', 'John', Decimal('16.49376228'), 1, 41),
#  ('UT_Meet', 'E0507', 'M', 100, 'Breaststroke', '1', 'U422', 'UTAustin', 'P614836', 'Benjamin', Decimal('16.51613435'), 1, 42)]

# %%
# %%sql
# INSERT INTO Swim VALUES
#     ('2', 'E0307', 'SouthConfed', 'P608878', 1, 89.99),
#     ('2', 'E0307', 'SouthConfed', 'P944240', 2, 89.99),
#     ('2', 'E0307', 'SouthConfed', 'P482516', 3, 89.99),
#     ('2', 'E0307', 'SouthConfed', 'P925991', 4, 89.99);
# Out:
# 4 rows affected.
# []

# %%
# %%sql
# DROP VIEW IF EXISTS meet_group_time_rank CASCADE;
# CREATE VIEW meet_group_time_rank AS
# SELECT sw.meet_name,
#     sw.event_id, e.gender, e.distance, s.stroke,
#     sw.heat_id,
#     --only choose the best time of the group in an event
#     CASE WHEN
#         (RANK() OVER
#         (PARTITION BY sw.meet_name, sw.event_id, Org.id
#          ORDER BY Sum(t) ASC) )=1
#     THEN
#         RANK() OVER
#         (PARTITION BY sw.meet_name, sw.event_id ORDER BY Sum(t) ASC)
#     END AS group_event_rank,
#     Sum(t) AS group_time,
#     Org.id AS org_id, Org.name AS school,
#     RANK() OVER
#     (PARTITION BY sw.meet_name, sw.event_id, Org.id
#         ORDER BY Sum(t) ASC)
#         AS school_rank
#
# FROM Swim sw
# INNER JOIN relay_events r ON r.event_id = sw.event_id
# INNER JOIN Event e ON sw.event_id = e.id
# INNER JOIN StrokeOf s ON s.event_id = e.id AND s.leg=sw.leg
# INNER JOIN Participant p ON p.id = sw.participant_id
# INNER JOIN Org ON p.org_id = Org.id
# GROUP BY sw.meet_name, sw.event_id, e.gender, e.distance, s.stroke, sw.heat_id, Org.id, Org.name
# ORDER BY sw.meet_name, sw.event_id, group_event_rank ASC
# ;
#
#
# SELECT * FROM meet_group_time_rank;
# Out:
# Done.
# Done.
# 15 rows affected.
# [('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 1, Decimal('50.79403657'), 'U502', 'UTDallas', 1),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 2, Decimal('56.05009186'), 'U430', 'RICE', 1),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 3, Decimal('56.87285183'), 'U693', 'Baylor', 1),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 4, Decimal('56.90329114'), 'U422', 'UTAustin', 1),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 5, Decimal('64.80730855'), 'U203', 'UoH', 1),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '2', None, Decimal('359.96'), 'U693', 'Baylor', 2),
#  ('SouthConfed', 'E0422', 'F', 400, 'Medley', '1', 1, Decimal('45.957664606'), 'U693', 'Baylor', 1),
#  ('SouthConfed', 'E0422', 'F', 400, 'Medley', '1', 2, Decimal('50.410127235'), 'U203', 'UoH', 1),
#  ('SouthConfed', 'E0422', 'F', 400, 'Medley', '1', 3, Decimal('53.00847975'), 'U422', 'UTAustin', 1),
#  ('SouthConfed', 'E0422', 'F', 400, 'Medley', '1', 4, Decimal('53.07384230'), 'U430', 'RICE', 1),
#  ('SouthConfed', 'E0422', 'F', 400, 'Medley', '1', 5, Decimal('55.97567330'), 'U502', 'UTDallas', 1),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 1, Decimal('47.974010357'), 'U203', 'UoH', 1),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 2, Decimal('54.07013204'), 'U422', 'UTAustin', 1),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 3, Decimal('54.74478667'), 'U430', 'RICE', 1),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 4, Decimal('57.17000413'), 'U502', 'UTDallas', 1)]

# %%
# %%sql
# DROP VIEW IF EXISTS meet_group_info;
# CREATE VIEW meet_group_info AS
# SELECT sw.meet_name, sw.event_id,  e.gender, e.distance, s.stroke, sw.heat_id,
#             m.group_event_rank,
#             m.group_time,
#             Org.id AS org_id, Org.name AS school,
#             sw.leg,
#             sw.participant_id, p.name AS swimmer_name,
#             t AS individual_time
# FROM Swim sw
# INNER JOIN relay_events r ON r.event_id = sw.event_id
# INNER JOIN Event e ON sw.event_id = e.id
# INNER JOIN StrokeOf s ON s.event_id = e.id AND s.leg=sw.leg
# INNER JOIN Participant p ON p.id = sw.participant_id
# INNER JOIN Org ON p.org_id = Org.id
# INNER JOIN meet_group_time_rank m
# ON sw.meet_name=m.meet_name
#     AND sw.event_id=m.event_id
#     AND sw.heat_id=m.heat_id
#     AND Org.id=m.org_id
#
# ORDER BY sw.meet_name, sw.event_id, sw.heat_id, group_event_rank,  leg ASC
#
# ;
#
# SELECT * FROM meet_group_info;
# Out:
# Done.
# Done.
# 60 rows affected.
# [('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 1, Decimal('50.79403657'), 'U502', 'UTDallas', 1, 'P411523', 'Santiago', Decimal('13.38451082')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 1, Decimal('50.79403657'), 'U502', 'UTDallas', 2, 'P782093', 'Diego', Decimal('12.62364375')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 1, Decimal('50.79403657'), 'U502', 'UTDallas', 3, 'P414627', 'Mason', Decimal('11.80007796')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 1, Decimal('50.79403657'), 'U502', 'UTDallas', 4, 'P551881', 'Ethan', Decimal('12.98580404')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 2, Decimal('56.05009186'), 'U430', 'RICE', 1, 'P946656', 'Caden', Decimal('12.16235924')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 2, Decimal('56.05009186'), 'U430', 'RICE', 2, 'P363719', 'Ethan', Decimal('13.16446824')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 2, Decimal('56.05009186'), 'U430', 'RICE', 3, 'P326379', 'Carter', Decimal('14.58001008')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 2, Decimal('56.05009186'), 'U430', 'RICE', 4, 'P774555', 'Muhammad', Decimal('16.1432543')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 3, Decimal('56.87285183'), 'U693', 'Baylor', 1, 'P608878', 'Lucas', Decimal('15.18511175')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 3, Decimal('56.87285183'), 'U693', 'Baylor', 2, 'P944240', 'Jackson', Decimal('13.64228411')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 3, Decimal('56.87285183'), 'U693', 'Baylor', 3, 'P482516', 'Jacob', Decimal('13.19878974')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 3, Decimal('56.87285183'), 'U693', 'Baylor', 4, 'P925991', 'Samuel', Decimal('14.84666623')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 4, Decimal('56.90329114'), 'U422', 'UTAustin', 1, 'P320247', 'Mateo', Decimal('11.84758772')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1', 4, Decimal('56.90329114'), 'U422', 'UTAustin', 2, 'P375195', 'Benjamin', Decimal('16.12068625')),
#  ('SouthConfed', 'E0307', 'M', 400, 'Medley', '1',
),
#  ('SouthConfed', 'E0422', 'F', 400, 'Medley', '1', 5, Decimal('55.97567330'), 'U502', 'UTDallas', 3, 'P419077', 'Serena', Decimal('14.64330622')),
#  ('SouthConfed', 'E0422', 'F', 400, 'Medley', '1', 5, Decimal('55.97567330'), 'U502', 'UTDallas', 4, 'P326451', 'Lisa', Decimal('10.90846627')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 1, Decimal('47.974010357'), 'U203', 'UoH', 1, 'P266751', 'Amy', Decimal('13.86489535')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 1, Decimal('47.974010357'), 'U203', 'UoH', 2, 'P263779', 'Catheine', Decimal('9.746428197')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 1, Decimal('47.974010357'), 'U203', 'UoH', 3, 'P251935', 'Frances', Decimal('13.68586749')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 1, Decimal('47.974010357'), 'U203', 'UoH', 4, 'P938149', 'Aditi', Decimal('10.67681932')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 2, Decimal('54.07013204'), 'U422', 'UTAustin', 1, 'P126504', 'Vivian', Decimal('13.71464987')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 2, Decimal('54.07013204'), 'U422', 'UTAustin', 2, 'P697891', 'Xu', Decimal('12.45305563')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 2, Decimal('54.07013204'), 'U422', 'UTAustin', 3, 'P451746', 'Chunhua', Decimal('15.63138426')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 2, Decimal('54.07013204'), 'U422', 'UTAustin', 4, 'P484371', 'Natalie', Decimal('12.27104228')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 3, Decimal('54.74478667'), 'U430', 'RICE', 1, 'P787951', 'Dorothy', Decimal('15.63473997')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 3, Decimal('54.74478667'), 'U430', 'RICE', 2, 'P844138', 'Karen', Decimal('9.68576')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 3, Decimal('54.74478667'), 'U430', 'RICE', 3, 'P744201', 'Betty', Decimal('15.16301552')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 3, Decimal('54.74478667'), 'U430', 'RICE', 4, 'P892923', 'Carol', Decimal('14.26127118')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 4, Decimal('57.17000413'), 'U502', 'UTDallas', 1, 'P326451', 'Lisa', Decimal('15.1995097')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 4, Decimal('57.17000413'), 'U502', 'UTDallas', 2, 'P126715', 'Rebecca', Decimal('13.62935128')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 4, Decimal('57.17000413'), 'U502', 'UTDallas', 3, 'P761841', 'Valeria', Decimal('13.89330374')),
#  ('SouthConfed', 'E1107', 'F', 400, 'Breaststroke', '1', 4, Decimal('57.17000413'), 'U502', 'UTDallas', 4, 'P152708', 'Aliah', Decimal('14.44783941'))]

# %%
# %%sql
# --fetch swimmer names
# SELECT m1.participant_id
# FROM meet_group_info m1
#     WHERE m1.meet_name='SouthConfed'
#          AND m1.event_id='E0307'
#          AND m1.heat_id='1'
#          AND m1.org_id='U502'
# ;
# Out:
# 4 rows affected.
# [('P411523',), ('P782093',), ('P414627',), ('P551881',)]

# %%
# %%sql
#
# DROP FUNCTION IF EXISTS GetMeetInfoInd(meet_name_value VARCHAR(20));
# CREATE OR REPLACE FUNCTION GetMeetInfoInd (meet_name_value VARCHAR(20))
# RETURNS TABLE
# (gender VARCHAR(1), distance INT, stroke VARCHAR(20),
#  heat_id VARCHAR(10),
#  org_id VARCHAR(10),
#  school VARCHAR(20),
#  participant_id VARCHAR(10),
#  swimmer_name VARCHAR(20),
#  event_rank bigint ,
#  t DECIMAL)
# AS $$
#     BEGIN
#         RETURN QUERY (SELECT
#         m.gender, m.distance, m.stroke,
#         m.heat_id,
#         m.org_id, m.school,
#         m.participant_id, m.swimmer_name,
#         m.event_rank, m.t
#         FROM meet_individual_info m WHERE m.meet_name = meet_name_value);
#     END $$
# LANGUAGE plpgsql
# STABLE;
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# SELECT gender, distance, stroke,
#         heat_id,
#         org_id, school,
#         participant_id, swimmer_name,
#         event_rank, t
#         FROM meet_individual_info WHERE meet_name ='NCAA_Summer';
# Out:
# 423 rows affected.
# [('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P544338', 'William', 4, Decimal('11.6987')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P891266', 'Robert', 6, Decimal('11.74815471')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P451875', 'Elijah', 7, Decimal('11.77619264')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P966483', 'Aiden', 10, Decimal('11.85759413')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P390796', 'Lucas', 15, Decimal('12.0014812')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P925991', 'Samuel', 18, Decimal('12.07877553')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P686315', 'Noah', 25, Decimal('12.41570303')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P326379', 'Carter', 35, Decimal('12.7967373')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P944240', 'Jackson', 37, Decimal('12.85323514')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P364479', 'William', 38, Decimal('12.9350458')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P619446', 'Lai', 49, Decimal('13.33658822')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P350887', 'Noah', 50, Decimal('13.35034408')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P664643', 'John', 57, Decimal('13.53774055')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P852515', 'Jacob', 59, Decimal('13.66983274')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P132246', 'Armaan', 62, Decimal('13.78668953')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P913591', 'Joseph', 67, Decimal('13.89281903')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P334035', 'David', 74, Decimal('14.15704974')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P960306', 'Samuel', 80, Decimal('14.36935546')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P848881', 'Arnav', 83, Decimal('14.51010493')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P879800', 'Pedro', 88, Decimal('14.74922689')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P109919', 'Daven', 95, Decimal('15.02830005')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P716897', 'Alexander', 98, Decimal('15.11526456')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P712128', 'Ryan', 103, Decimal('15.25016301')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P490897', 'Rohan', 107, Decimal('15.39012376')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P216672', 'Jimmy', 117, Decimal('15.79399678')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P411523', 'Santiago', 133, Decimal('16.3748389')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P948241', 'Ishaan', 136, Decimal('16.40396974')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P478858', 'Neil', 137, Decimal('16.40635479')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P837450', 'Liam', None, Decimal('13.04410977')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P853409', 'George', None, Decimal('15.51859109')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P482516', 'Jacob', None, Decimal('16.23452107')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P774555', 'Muhammad', None, Decimal('13.97837989')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P424921', 'Joshua', None, Decimal('15.10959752')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P627706', 'Aiden', None, Decimal('14.3177182')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P158289', 'Edward', None, Decimal('15.16944529')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P581736', 'Aiden', None, Decimal('14.87364167')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P849004', 'Jason', None, Decimal('16.08096591')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P319962', 'Dan', None, Decimal('15.93167917')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P614836', 'Benjamin', None, Decimal('13.16557278')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P414627', 'Mason', None, Decimal('15.99758282')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P999815', 'Amir', 1, Decimal('11.5898')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P614836', 'Benjamin', 2, Decimal('11.60800596')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P375195', 'Benjamin', 8, Decimal('11.81469425')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P690976', 'David', 12, Decimal('11.91029952')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P615133', 'Jack', 21, Decimal('12.23758573')),
#  ('M', 100, 'Freestyle', '2', 'U502', 'UTDallas', 'P446185', 'Rohan', 22, Decimal('12.24485412')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P994822', 'Jeremiah', 23, Decimal('12.36843211')),
#  ('M', 100, 'Freestyle', '2', 'U693', 'Baylor', 'P720454', 'Matias', 28, Decimal('12.56492605')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P855086', 'Jeremy', 29, Decimal('12.60083047')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P998753', 'Aryan', 34, Decimal('12.78151502')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P571660', 'Charles', 36, Decimal('12.83787305')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', '
),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P779068', 'Barbara', 92, Decimal('15.01077375')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P402065', 'Lindsay', 96, Decimal('15.03067709')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P450947', 'Isabel', 99, Decimal('15.12498059')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P315434', 'Michelle', 102, Decimal('15.1812186')),
#  ('M', 100, 'Freestyle', '3', 'U502', 'UTDallas', 'P772269', 'Janet', 106, Decimal('15.34075226')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P393193', 'Charline', 110, Decimal('15.51948156')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P562400', 'Christine', 112, Decimal('15.63315995')),
#  ('M', 100, 'Freestyle', '3', 'U502', 'UTDallas', 'P296082', 'Fatima', 116, Decimal('15.75410247')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P717486', 'Fada', 121, Decimal('15.94297716')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P713611', 'Winter', 130, Decimal('16.29096987')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P834447', 'Pamela', 131, Decimal('16.29509854')),
#  ('M', 100, 'Freestyle', '3', 'U502', 'UTDallas', 'P676479', 'Susan', 138, Decimal('16.48348075')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P451746', 'Chunhua', 145, Decimal('16.62890189')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P305399', 'Marian', 146, Decimal('16.68605254')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P306538', 'Toni', 151, Decimal('16.89802727')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P643181', 'Amanda', 155, Decimal('17.12245624')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P313609', 'Anjali', 156, Decimal('17.21586535')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P595277', 'Alda', 160, Decimal('17.57399746')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P844138', 'Karen', 161, Decimal('17.68036563')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P497862', 'Loretta', 162, Decimal('17.83103051')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P673060', 'Shreya', 163, Decimal('17.99095688')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P503806', 'Ruth', 166, Decimal('18.3687771')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P420213', 'Augustin', 13, Decimal('11.94360744')),
#  ('M', 100, 'Freestyle', '4', 'U502', 'UTDallas', 'P414627', 'Mason', 14, Decimal('11.96001619')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P853409', 'George', 26, Decimal('12.52489882')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P298187', 'Ryan', 32, Decimal('12.74124913')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P837450', 'Liam', 41, Decimal('13.02380132')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P581736', 'Aiden', 46, Decimal('13.18581297')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P139417', 'Ye', 53, Decimal('13.46240041')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P774555', 'Muhammad', 56, Decimal('13.53054363')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P424921', 'Joshua', 68, Decimal('13.89834756')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P674970', 'Santiago', 70, Decimal('13.95993742')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P482516', 'Jacob', 94, Decimal('15.01749948')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P209774', 'Nicky', 105, Decimal('15.31661125')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P194002', 'Suraj', 114, Decimal('15.70183794')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P178934', 'James', 125, Decimal('16.13422424')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P868463', 'Christopher', 134, Decimal('16.38907675')),
#  ('M', 100, 'Freestyle', '4', 'U502', 'UTDallas', 'P123639', 'Matt', 139, Decimal('16.50993404')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P801129', 'Christopher', 142, Decimal('16.55176257')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P307392', 'Michael', 144, Decimal('16.61100287')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P362851', 'Carolyn', 148, Decimal('16.82289323')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P363719', 'Ethan', 165, Decimal('18.28778595')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P720454', 'Matias', None, Decimal('16.55663331')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P948241', 'Ishaan', None, Decimal('18.18587836')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P216672', 'Jimmy', None, Decimal('15.89148813')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P334035', 'David', None, Decimal('14.18824084')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P478858', 'Neil', None, Decimal('17.46121026')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P132246', 'Armaan', None, Decimal('16.53442993')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P855086', 'Jeremy', None, Decimal('13.80138323')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P994822', 'Jeremiah', None, Decimal('16.94299984')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P373735', 'Logan', None, Decimal('17.30623055')),
#  ('M', 100, 'Freestyle', '4', 'U422', 'UTAustin', 'P813991', 'Daniel', None, Decimal('16.78222465')),
#  ('M', 100, 'Freestyle', '4', 'U422', 'UTAustin', 'P350887', 'Noah', None, Decimal('13.83993914')),
#  ('M', 100, 'Freestyle', '4', 'U422', 'UTAustin', 'P343775', 'Daniel', None, Decimal('16.85955895')),
#  ('M', 100, 'Freestyle', '4', 'U502', 'UTDallas', 'P446185', 'Rohan', None, Decimal('17.33782063')),
#  ('M', 100, 'Freestyle', '4', 'U502', 'UTDallas', '
),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P891266', 'Robert', 77, Decimal('13.93884592')),
#  ('M', 200, 'Medley', '3', 'U502', 'UTDallas', 'P411523', 'Santiago', 80, Decimal('14.07321917')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P837450', 'Liam', 83, Decimal('14.26271601')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P375195', 'Benjamin', 86, Decimal('14.41267227')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P993334', 'Lucky', 89, Decimal('14.5045356')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P334035', 'David', 90, Decimal('14.54220634')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P544338', 'William', 94, Decimal('14.79676062')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P627706', 'Aiden', 97, Decimal('14.83557756')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P608878', 'Lucas', 112, Decimal('15.5557161')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P712128', 'Ryan', 114, Decimal('15.76992214')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P998753', 'Aryan', 117, Decimal('15.93672051')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P109919', 'Daven', 119, Decimal('16.10024716')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P158289', 'Edward', 120, Decimal('16.19679941')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P716897', 'Alexander', 122, Decimal('16.32750494')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P503886', 'Chaya', 1, Decimal('12.85445561')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P393193', 'Charline', 2, Decimal('12.92320517')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P844138', 'Karen', 3, Decimal('13.11523755')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P776309', 'Maxine', 4, Decimal('13.18262387')),
#  ('F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P126715', 'Rebecca', 5, Decimal('13.3534012')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P308956', 'Stephanie', 6, Decimal('13.5318357')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P514806', 'Elizabeth', 7, Decimal('13.66351136')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P257391', 'Amanda', 8, Decimal('13.83855238')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P834447', 'Pamela', 9, Decimal('13.97600229')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P174047', 'Margaret', 10, Decimal('14.17246815')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P686988', 'Debra', 11, Decimal('14.27119624')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P779068', 'Barbara', 12, Decimal('14.34946009')),
#  ('F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P419077', 'Serena', 13, Decimal('14.47646258')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P561028', 'Xian', 14, Decimal('14.5793366')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P596208', 'Jennifer', 15, Decimal('14.62144151')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P422145', 'Rose', 16, Decimal('14.68704108')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P263690', 'Gina', 17, Decimal('14.84281111')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P870590', 'Biyu', 18, Decimal('15.03067638')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P650269', 'Gloria', 19, Decimal('15.17222658')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P938149', 'Aditi', 20, Decimal('15.23706728')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P402065', 'Lindsay', 21, Decimal('15.41220824')),
#  ('F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P326451', 'Lisa', 22, Decimal('15.50015794')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P503806', 'Ruth', 23, Decimal('15.68626948')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P146456', 'Akilah', 24, Decimal('15.76690657')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P744201', 'Betty', 25, Decimal('15.96249728')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P884623', 'Geneva', 26, Decimal('16.15926578')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P828862', 'Irma', 27, Decimal('16.25308419')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P108977', 'Anna', 28, Decimal('16.35778623')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P801697', 'Amy', 29, Decimal('16.52310095')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P896191', 'Elizabeth', 30, Decimal('16.60067915')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P251935', 'Frances', 31, Decimal('16.61680876')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P691294', 'Stephanie', 32, Decimal('17.07473989')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P831119', 'Xi', 33, Decimal('17.15676598')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P263779', 'Catheine', 34, Decimal('17.25046277')),
#  ('F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P187734', 'Mary', 35, Decimal('17.36299494')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P354503', 'Patricia', 36, Decimal('17.47486193')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P451746', 'Chunhua', 37, Decimal('17.48222495')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P831119', 'Xi', 1, Decimal('9.859423887')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P834447', 'Pamela', 2, Decimal('10.2721285')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P710107', 'Donny', 5, Decimal('10.4634547')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P776309', 'Maxine', 7, Decimal('10.60252782')),
#  ('M', 200, 'Butterfly', '1', 'U502', 'UTDallas', '
),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P619446', 'Lai', 23, Decimal('12.02471907')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P109919', 'Daven', 25, Decimal('12.11817717')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P581736', 'Aiden', 27, Decimal('12.28975713')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P350087', 'Nicolas', 29, Decimal('12.5316226')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P837450', 'Liam', 31, Decimal('12.74052442')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P307392', 'Michael', 35, Decimal('12.957561')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P853409', 'George', 38, Decimal('13.07306192')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P139417', 'Ye', 39, Decimal('13.13940342')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P966483', 'Aiden', 41, Decimal('13.21595562')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P852515', 'Jacob', 43, Decimal('13.3773915')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P615133', 'Jack', 45, Decimal('13.45466518')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P294836', 'Richard', 48, Decimal('13.59818685')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P362851', 'Carolyn', 51, Decimal('13.72238641')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P132246', 'Armaan', 52, Decimal('13.75667862')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P686315', 'Noah', 55, Decimal('13.94830597')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P948241', 'Ishaan', 59, Decimal('14.10645402')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P691951', 'Mohammad', 64, Decimal('14.30533724')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P490897', 'Rohan', 65, Decimal('14.36350799')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P551881', 'Ethan', 66, Decimal('14.39673016')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P857171', 'Sebastian', 68, Decimal('14.55907188')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P664643', 'John', 70, Decimal('14.71295141')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P627706', 'Aiden', 73, Decimal('14.83268054')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P674970', 'Santiago', 74, Decimal('14.84354777')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P420213', 'Augustin', 78, Decimal('15.02888843')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P926423', 'Deven', 79, Decimal('15.24121473'))]

# %%
# %%sql
# SELECT * FROM GetMeetInfoInd('NCAA_Summer');
# Out:
# 423 rows affected.
# [('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P544338', 'William', 4, Decimal('11.6987')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P891266', 'Robert', 6, Decimal('11.74815471')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P451875', 'Elijah', 7, Decimal('11.77619264')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P966483', 'Aiden', 10, Decimal('11.85759413')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P390796', 'Lucas', 15, Decimal('12.0014812')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P925991', 'Samuel', 18, Decimal('12.07877553')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P686315', 'Noah', 25, Decimal('12.41570303')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P326379', 'Carter', 35, Decimal('12.7967373')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P944240', 'Jackson', 37, Decimal('12.85323514')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P364479', 'William', 38, Decimal('12.9350458')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P619446', 'Lai', 49, Decimal('13.33658822')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P350887', 'Noah', 50, Decimal('13.35034408')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P664643', 'John', 57, Decimal('13.53774055')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P852515', 'Jacob', 59, Decimal('13.66983274')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P132246', 'Armaan', 62, Decimal('13.78668953')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P913591', 'Joseph', 67, Decimal('13.89281903')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P334035', 'David', 74, Decimal('14.15704974')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P960306', 'Samuel', 80, Decimal('14.36935546')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P848881', 'Arnav', 83, Decimal('14.51010493')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P879800', 'Pedro', 88, Decimal('14.74922689')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P109919', 'Daven', 95, Decimal('15.02830005')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P716897', 'Alexander', 98, Decimal('15.11526456')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P712128', 'Ryan', 103, Decimal('15.25016301')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P490897', 'Rohan', 107, Decimal('15.39012376')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P216672', 'Jimmy', 117, Decimal('15.79399678')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P411523', 'Santiago', 133, Decimal('16.3748389')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P948241', 'Ishaan', 136, Decimal('16.40396974')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P478858', 'Neil', 137, Decimal('16.40635479')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P837450', 'Liam', None, Decimal('13.04410977')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P853409', 'George', None, Decimal('15.51859109')),
#  ('M', 100, 'Freestyle', '1', 'U693', 'Baylor', 'P482516', 'Jacob', None, Decimal('16.23452107')),
#  ('M', 100, 'Freestyle', '1', 'U430', 'RICE', 'P774555', 'Muhammad', None, Decimal('13.97837989')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P424921', 'Joshua', None, Decimal('15.10959752')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P627706', 'Aiden', None, Decimal('14.3177182')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P158289', 'Edward', None, Decimal('15.16944529')),
#  ('M', 100, 'Freestyle', '1', 'U203', 'UoH', 'P581736', 'Aiden', None, Decimal('14.87364167')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P849004', 'Jason', None, Decimal('16.08096591')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P319962', 'Dan', None, Decimal('15.93167917')),
#  ('M', 100, 'Freestyle', '1', 'U422', 'UTAustin', 'P614836', 'Benjamin', None, Decimal('13.16557278')),
#  ('M', 100, 'Freestyle', '1', 'U502', 'UTDallas', 'P414627', 'Mason', None, Decimal('15.99758282')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P999815', 'Amir', 1, Decimal('11.5898')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P614836', 'Benjamin', 2, Decimal('11.60800596')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P375195', 'Benjamin', 8, Decimal('11.81469425')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P690976', 'David', 12, Decimal('11.91029952')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P615133', 'Jack', 21, Decimal('12.23758573')),
#  ('M', 100, 'Freestyle', '2', 'U502', 'UTDallas', 'P446185', 'Rohan', 22, Decimal('12.24485412')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P994822', 'Jeremiah', 23, Decimal('12.36843211')),
#  ('M', 100, 'Freestyle', '2', 'U693', 'Baylor', 'P720454', 'Matias', 28, Decimal('12.56492605')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P855086', 'Jeremy', 29, Decimal('12.60083047')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P998753', 'Aryan', 34, Decimal('12.78151502')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P571660', 'Charles', 36, Decimal('12.83787305')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P531550', 'David', 40, Decimal('13.00853035')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P849004', 'Jason', 43, Decimal('13.11553992')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P691951', 'Mohammad', 48, Decimal('13.26895283')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P373735', 'Logan', 52, Decimal('13.43104344')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P343775', 'Daniel', 54, Decimal('13.5179504')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P813991', 'Daniel', 58, Decimal('13.62226847')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P627706', 'Aiden', 64, Decimal('13.80495256')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P114140', 'Nikhil', 65, Decimal('13.81376416')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P246719', 'Liam', 79, Decimal('14.33638363')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P877604', 'David', 87, Decimal('14.72271235')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P158289', 'Edward', 93, Decimal('15.01485778')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P319962', 'Dan', 100, Decimal('15.12591199')),
#  ('M', 100, 'Freestyle', '2', 'U502', 'UTDallas', 'P294836', 'Richard', 108, Decimal('15.46315231')),
#  ('M', 100, 'Freestyle', '2', 'U502', 'UTDallas', 'P814834', 'Mason', 113, Decimal('15.65476904')),
#  ('M', 100, 'Freestyle', '2', 'U502', 'UTDallas', 'P782093', 'Diego', 118, Decimal('15.88735199')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P320247', 'Mateo', 123, Decimal('16.07320422')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P472703', 'Alejandro', 132, Decimal('16.34337589')),
#  ('M', 100, 'Freestyle', '2', 'U693', 'Baylor', 'P926423', 'Deven', 140, Decimal('16.5277275')),
#  ('M', 100, 'Freestyle', '2', 'U693', 'Baylor', 'P960306', 'Samuel', None, Decimal('14.64154804')),
#  ('M', 100, 'Freestyle', '2', 'U693', 'Baylor', 'P837450', 'Liam', None, Decimal('15.29164391')),
#  ('M', 100, 'Freestyle', '2', 'U693', 'Baylor', 'P925991', 'Samuel', None, Decimal('14.88796386')),
#  ('M', 100, 'Freestyle', '2', 'U693', 'Baylor', 'P853409', 'George', None, Decimal('16.39628913')),
#  ('M', 100, 'Freestyle', '2', 'U693', 'Baylor', 'P362851', 'Carolyn', None, Decimal('17.04155095')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P774555', 'Muhammad', None, Decimal('16.17676112')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P852515', 'Jacob', None, Decimal('15.74288599')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P334035', 'David', None, Decimal('15.55049196')),
#  ('M', 100, 'Freestyle', '2', 'U430', 'RICE', 'P139417', 'Ye', None, Decimal('14.07580003')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P420213', 'Augustin', None, Decimal('16.28594043')),
#  ('M', 100, 'Freestyle', '2', 'U203', 'UoH', 'P581736', 'Aiden', None, Decimal('16.87723462')),
#  ('M', 100, 'Freestyle', '2', 'U422', 'UTAustin', 'P350887', 'Noah', None, Decimal('13.91027269')),
#  ('M', 100, 'Freestyle', '2', 'U502', 'UTDallas', 'P364479', 'William', None, Decimal('16.27118429')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P358275', 'Sada', 3, Decimal('11.64234693')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P171587', 'Pratiksha', 5, Decimal('11.70617453')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P722618', 'Yolanda', 9, Decimal('11.85598147')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P132685', 'Ana Paula', 11, Decimal('11.86828583')),
#  ('M', 100, 'Freestyle', '3', 'U502', 'UTDallas', 'P419077', 'Serena', 16, Decimal('12.04906499')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P801697', 'Amy', 17, Decimal('12.06544583')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P518763', 'Linda', 19, Decimal('12.12878686')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P266751', 'Amy', 20, Decimal('12.21837815')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P831119', 'Xi', 24, Decimal('12.37327832')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P561028', 'Xian', 27, Decimal('12.54925464')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P962214', 'Saya', 30, Decimal('12.61267382')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P198583', 'Natalie', 31, Decimal('12.62829217')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P102099', 'Rose', 33, Decimal('12.77938896')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P493853', 'Terry', 39, Decimal('12.9752733')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P251935', 'Frances', 44, Decimal('13.11632395')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P768448', 'Cynthia', 47, Decimal('13.2144709')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P484371', 'Natalie', 51, Decimal('13.36662219')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P282743', 'Samantha', 55, Decimal('13.52452465')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P126504', 'Vivian', 60, Decimal('13.68146573')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P453891', 'Amanda', 61, Decimal('13.77185263')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P354503', 'Patricia', 72, Decimal('14.03698192')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P552426', 'Xilin', 76, Decimal('14.22006972')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P744651', 'Linda', 77, Decimal('14.29195673')),
#  ('M', 100, 'Freestyle', '3', 'U502', 'UTDallas', 'P544348', 'Sophie', 81, Decimal('14.38918012')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P214547', 'Katherine', 82, Decimal('14.49850549')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P174047', 'Margaret', 84, Decimal('14.53633902')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P744201', 'Betty', 86, Decimal('14.65523183')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P163990', 'Ava', 89, Decimal('14.84995278')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P779068', 'Barbara', 92, Decimal('15.01077375')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P402065', 'Lindsay', 96, Decimal('15.03067709')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P450947', 'Isabel', 99, Decimal('15.12498059')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P315434', 'Michelle', 102, Decimal('15.1812186')),
#  ('M', 100, 'Freestyle', '3', 'U502', 'UTDallas', 'P772269', 'Janet', 106, Decimal('15.34075226')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P393193', 'Charline', 110, Decimal('15.51948156')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P562400', 'Christine', 112, Decimal('15.63315995')),
#  ('M', 100, 'Freestyle', '3', 'U502', 'UTDallas', 'P296082', 'Fatima', 116, Decimal('15.75410247')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P717486', 'Fada', 121, Decimal('15.94297716')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P713611', 'Winter', 130, Decimal('16.29096987')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P834447', 'Pamela', 131, Decimal('16.29509854')),
#  ('M', 100, 'Freestyle', '3', 'U502', 'UTDallas', 'P676479', 'Susan', 138, Decimal('16.48348075')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P451746', 'Chunhua', 145, Decimal('16.62890189')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P305399', 'Marian', 146, Decimal('16.68605254')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P306538', 'Toni', 151, Decimal('16.89802727')),
#  ('M', 100, 'Freestyle', '3', 'U203', 'UoH', 'P643181', 'Amanda', 155, Decimal('17.12245624')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P313609', 'Anjali', 156, Decimal('17.21586535')),
#  ('M', 100, 'Freestyle', '3', 'U422', 'UTAustin', 'P595277', 'Alda', 160, Decimal('17.57399746')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P844138', 'Karen', 161, Decimal('17.68036563')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P497862', 'Loretta', 162, Decimal('17.83103051')),
#  ('M', 100, 'Freestyle', '3', 'U693', 'Baylor', 'P673060', 'Shreya', 163, Decimal('17.99095688')),
#  ('M', 100, 'Freestyle', '3', 'U430', 'RICE', 'P503806', 'Ruth', 166, Decimal('18.3687771')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P420213', 'Augustin', 13, Decimal('11.94360744')),
#  ('M', 100, 'Freestyle', '4', 'U502', 'UTDallas', 'P414627', 'Mason', 14, Decimal('11.96001619')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P853409', 'George', 26, Decimal('12.52489882')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P298187', 'Ryan', 32, Decimal('12.74124913')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P837450', 'Liam', 41, Decimal('13.02380132')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P581736', 'Aiden', 46, Decimal('13.18581297')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P139417', 'Ye', 53, Decimal('13.46240041')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P774555', 'Muhammad', 56, Decimal('13.53054363')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P424921', 'Joshua', 68, Decimal('13.89834756')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P674970', 'Santiago', 70, Decimal('13.95993742')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P482516', 'Jacob', 94, Decimal('15.01749948')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P209774', 'Nicky', 105, Decimal('15.31661125')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P194002', 'Suraj', 114, Decimal('15.70183794')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P178934', 'James', 125, Decimal('16.13422424')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P868463', 'Christopher', 134, Decimal('16.38907675')),
#  ('M', 100, 'Freestyle', '4', 'U502', 'UTDallas', 'P123639', 'Matt', 139, Decimal('16.50993404')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P801129', 'Christopher', 142, Decimal('16.55176257')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P307392', 'Michael', 144, Decimal('16.61100287')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P362851', 'Carolyn', 148, Decimal('16.82289323')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P363719', 'Ethan', 165, Decimal('18.28778595')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P720454', 'Matias', None, Decimal('16.55663331')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P948241', 'Ishaan', None, Decimal('18.18587836')),
#  ('M', 100, 'Freestyle', '4', 'U693', 'Baylor', 'P216672', 'Jimmy', None, Decimal('15.89148813')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P334035', 'David', None, Decimal('14.18824084')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P478858', 'Neil', None, Decimal('17.46121026')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P132246', 'Armaan', None, Decimal('16.53442993')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P855086', 'Jeremy', None, Decimal('13.80138323')),
#  ('M', 100, 'Freestyle', '4', 'U430', 'RICE', 'P994822', 'Jeremiah', None, Decimal('16.94299984')),
#  ('M', 100, 'Freestyle', '4', 'U203', 'UoH', 'P373735', 'Logan', None, Decimal('17.30623055')),
#  ('M', 100, 'Freestyle', '4', 'U422', 'UTAustin', 'P813991', 'Daniel', None, Decimal('16.78222465')),
#  ('M', 100, 'Freestyle', '4', 'U422', 'UTAustin', 'P350887', 'Noah', None, Decimal('13.83993914')),
#  ('M', 100, 'Freestyle', '4', 'U422', 'UTAustin', 'P343775', 'Daniel', None, Decimal('16.85955895')),
#  ('M', 100, 'Freestyle', '4', 'U502', 'UTDallas', 'P446185', 'Rohan', None, Decimal('17.33782063')),
#  ('M', 100, 'Freestyle', '4', 'U502', 'UTDallas', 'P814834', 'Mason', None, Decimal('17.01328429')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P174047', 'Margaret', 24, Decimal('11.55789')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P686988', 'Debra', 34, Decimal('12.2234')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P717486', 'Fada', 37, Decimal('12.37693376')),
#  ('M', 200, 'Medley', '1', 'U422', 'UTAustin', 'P512304', 'Maria', 38, Decimal('12.41766544')),
#  ('M', 200, 'Medley', '1', 'U422', 'UTAustin', 'P648329', 'Shirley', 45, Decimal('12.63890433')),
#  ('M', 200, 'Medley', '1', 'U502', 'UTDallas', 'P761841', 'Valeria', 48, Decimal('12.78481811')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P387891', 'June', 50, Decimal('12.83590553')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P171587', 'Pratiksha', 53, Decimal('12.94298989')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P643181', 'Amanda', 58, Decimal('13.13958708')),
#  ('M', 200, 'Medley', '1', 'U422', 'UTAustin', 'P834447', 'Pamela', 63, Decimal('13.31676473')),
#  ('M', 200, 'Medley', '1', 'U502', 'UTDallas', 'P544348', 'Sophie', 64, Decimal('13.36098695')),
#  ('M', 200, 'Medley', '1', 'U422', 'UTAustin', 'P650269', 'Gloria', 67, Decimal('13.55439857')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P518763', 'Linda', 69, Decimal('13.69878')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P776309', 'Maxine', 70, Decimal('13.70576857')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P497862', 'Loretta', 71, Decimal('13.73054872')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P132685', 'Ana Paula', 73, Decimal('13.81837457')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P870590', 'Biyu', 76, Decimal('13.90544205')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P975231', 'Kelsey', 81, Decimal('14.09482232')),
#  ('M', 200, 'Medley', '1', 'U422', 'UTAustin', 'P451746', 'Chunhua', 82, Decimal('14.17552066')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P358275', 'Sada', 88, Decimal('14.49954143')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P561028', 'Xian', 95, Decimal('14.80383614')),
#  ('M', 200, 'Medley', '1', 'U502', 'UTDallas', 'P477094', 'Joy', 99, Decimal('14.90350465')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P257391', 'Amanda', 102, Decimal('15.05953456')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P744651', 'Linda', 103, Decimal('15.15582819')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P308956', 'Stephanie', 105, Decimal('15.2502052')),
#  ('M', 200, 'Medley', '1', 'U502', 'UTDallas', 'P888246', 'Susan', 107, Decimal('15.33125716')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P514806', 'Elizabeth', 111, Decimal('15.45435268')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P892923', 'Carol', 113, Decimal('15.61505972')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P801697', 'Amy', 115, Decimal('15.80364721')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P713611', 'Winter', 116, Decimal('15.91251103')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P768448', 'Cynthia', 118, Decimal('16.07393214')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P266751', 'Amy', 121, Decimal('16.22098484')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P844138', 'Karen', 126, Decimal('16.50864067')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P759847', 'Victoria', 127, Decimal('16.58957992')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P503806', 'Ruth', 129, Decimal('16.78270687')),
#  ('M', 200, 'Medley', '1', 'U502', 'UTDallas', 'P419077', 'Serena', 130, Decimal('16.85917404')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P395940', 'Aida', 131, Decimal('17.19703123')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P198583', 'Natalie', None, Decimal('13.05579963')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P831119', 'Xi', None, Decimal('12.470765')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P893682', 'Xilin', None, Decimal('15.45031006')),
#  ('M', 200, 'Medley', '1', 'U693', 'Baylor', 'P240255', 'Hansika', None, Decimal('14.61895978')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P214547', 'Katherine', None, Decimal('16.43079364')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P944182', 'Abril', None, Decimal('13.17836356')),
#  ('M', 200, 'Medley', '1', 'U430', 'RICE', 'P962214', 'Saya', None, Decimal('14.35385682')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P263779', 'Catheine', None, Decimal('14.82261917')),
#  ('M', 200, 'Medley', '1', 'U203', 'UoH', 'P251935', 'Frances', None, Decimal('16.34765301')),
#  ('M', 200, 'Medley', '1', 'U422', 'UTAustin', 'P697891', 'Xu', None, Decimal('16.61721096')),
#  ('M', 200, 'Medley', '1', 'U502', 'UTDallas', 'P187734', 'Mary', None, Decimal('14.26662839')),
#  ('M', 200, 'Medley', '1', 'U502', 'UTDallas', 'P250591', 'Chrn', None, Decimal('16.43620776')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P259364', 'Amanda', 1, Decimal('9.65784')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P240255', 'Hansika', 4, Decimal('9.876524517')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P673060', 'Shreya', 5, Decimal('9.920128795')),
#  ('M', 200, 'Medley', '2', 'U502', 'UTDallas', 'P187734', 'Mary', 6, Decimal('10.06488443')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P552426', 'Xilin', 8, Decimal('10.17624508')),
#  ('M', 200, 'Medley', '2', 'U203', 'UoH', 'P306538', 'Toni', 10, Decimal('10.27461296')),
#  ('M', 200, 'Medley', '2', 'U430', 'RICE', 'P962214', 'Saya', 11, Decimal('10.31611006')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P313609', 'Anjali', 13, Decimal('10.3606922')),
#  ('M', 200, 'Medley', '2', 'U430', 'RICE', 'P385867', 'Wanda', 14, Decimal('10.42761111')),
#  ('M', 200, 'Medley', '2', 'U203', 'UoH', 'P710107', 'Donny', 15, Decimal('10.56720163')),
#  ('M', 200, 'Medley', '2', 'U430', 'RICE', 'P214547', 'Katherine', 16, Decimal('10.74569961')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P163990', 'Ava', 20, Decimal('11.21775506')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P596208', 'Jennifer', 21, Decimal('11.39609975')),
#  ('M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P314927', 'Karen', 22, Decimal('11.42698006')),
#  ('M', 200, 'Medley', '2', 'U430', 'RICE', 'P951470', 'Sarah', 25, Decimal('11.64423963')),
#  ('M', 200, 'Medley', '2', 'U502', 'UTDallas', 'P126715', 'Rebecca', 27, Decimal('11.73986518')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P198583', 'Natalie', 29, Decimal('11.84730055')),
#  ('M', 200, 'Medley', '2', 'U430', 'RICE', 'P239302', 'Patricia', 31, Decimal('11.86522163')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P831119', 'Xi', 33, Decimal('12.06361227')),
#  ('M', 200, 'Medley', '2', 'U430', 'RICE', 'P263690', 'Gina', 35, Decimal('12.22534474')),
#  ('M', 200, 'Medley', '2', 'U203', 'UoH', 'P493853', 'Terry', 39, Decimal('12.42516619')),
#  ('M', 200, 'Medley', '2', 'U430', 'RICE', 'P944182', 'Abril', 42, Decimal('12.50112519')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P102099', 'Rose', 44, Decimal('12.62401857')),
#  ('M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P545233', 'Carolyn', 46, Decimal('12.73675216')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P393193', 'Charline', 59, Decimal('13.16208447')),
#  ('M', 200, 'Medley', '2', 'U203', 'UoH', 'P996063', 'Stephanie', 62, Decimal('13.21443475')),
#  ('M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P500771', 'Kavya', 65, Decimal('13.39602667')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P722188', 'Irma', 72, Decimal('13.78928537')),
#  ('M', 200, 'Medley', '2', 'U203', 'UoH', 'P251935', 'Frances', 75, Decimal('13.89443365')),
#  ('M', 200, 'Medley', '2', 'U430', 'RICE', 'P862621', 'Mia', 87, Decimal('14.49461789')),
#  ('M', 200, 'Medley', '2', 'U203', 'UoH', 'P263779', 'Catheine', 91, Decimal('14.59758848')),
#  ('M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P697891', 'Xu', 93, Decimal('14.79137261')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P354503', 'Patricia', 98, Decimal('14.84280914')),
#  ('M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P305399', 'Marian', 100, Decimal('14.93087283')),
#  ('M', 200, 'Medley', '2', 'U502', 'UTDallas', 'P250591', 'Chrn', 101, Decimal('14.98760365')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P783509', 'Jessica', 104, Decimal('15.18051824')),
#  ('M', 200, 'Medley', '2', 'U693', 'Baylor', 'P893682', 'Xilin', 106, Decimal('15.25571549')),
#  ('M', 200, 'Medley', '2', 'U422', 'UTAustin', 'P408363', 'Sandra', 109, Decimal('15.42063285')),
#  ('M', 200, 'Medley', '2', 'U203', 'UoH', 'P643181', 'Amanda', None, Decimal('15.33703491')),
#  ('M', 200, 'Medley', '2', 'U203', 'UoH', 'P870590', 'Biyu', None, Decimal('14.04302873')),
#  ('M', 200, 'Medley', '2', 'U502', 'UTDallas', 'P761841', 'Valeria', None, Decimal('14.06470172')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P472703', 'Alejandro', 2, Decimal('9.698855155')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P944240', 'Jackson', 3, Decimal('9.751429104')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P581736', 'Aiden', 7, Decimal('10.14036131')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P919641', 'Thomas', 9, Decimal('10.23174148')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P281029', 'Michael', 12, Decimal('10.35813919')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P720454', 'Matias', 17, Decimal('10.91173197')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P362851', 'Carolyn', 18, Decimal('11.05938083')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P877604', 'David', 19, Decimal('11.0780158')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P813991', 'Daniel', 23, Decimal('11.55482064')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P946656', 'Caden', 26, Decimal('11.66506738')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P333827', 'John', 28, Decimal('11.77896')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P667298', 'Martin', 30, Decimal('11.84862579')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P194002', 'Suraj', 32, Decimal('11.86747216')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P132246', 'Armaan', 36, Decimal('12.35364569')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P852515', 'Jacob', 40, Decimal('12.44456371')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P614836', 'Benjamin', 43, Decimal('12.56180197')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P529632', 'Joseph', 47, Decimal('12.76123859')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P925991', 'Samuel', 49, Decimal('12.81919994')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P478858', 'Neil', 51, Decimal('12.87277164')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P216672', 'Jimmy', 52, Decimal('12.93454769')),
#  ('M', 200, 'Medley', '3', 'U502', 'UTDallas', 'P782093', 'Diego', 55, Decimal('13.06320008')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P307392', 'Michael', 56, Decimal('13.12589725')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P246719', 'Liam', 57, Decimal('13.13212094')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P420213', 'Augustin', 61, Decimal('13.19887088')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P691951', 'Mohammad', 66, Decimal('13.51138815')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P363719', 'Ethan', 68, Decimal('13.65719651')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P855086', 'Jeremy', 74, Decimal('13.83752956')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P891266', 'Robert', 77, Decimal('13.93884592')),
#  ('M', 200, 'Medley', '3', 'U502', 'UTDallas', 'P411523', 'Santiago', 80, Decimal('14.07321917')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P837450', 'Liam', 83, Decimal('14.26271601')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P375195', 'Benjamin', 86, Decimal('14.41267227')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P993334', 'Lucky', 89, Decimal('14.5045356')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P334035', 'David', 90, Decimal('14.54220634')),
#  ('M', 200, 'Medley', '3', 'U422', 'UTAustin', 'P544338', 'William', 94, Decimal('14.79676062')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P627706', 'Aiden', 97, Decimal('14.83557756')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P608878', 'Lucas', 112, Decimal('15.5557161')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P712128', 'Ryan', 114, Decimal('15.76992214')),
#  ('M', 200, 'Medley', '3', 'U430', 'RICE', 'P998753', 'Aryan', 117, Decimal('15.93672051')),
#  ('M', 200, 'Medley', '3', 'U693', 'Baylor', 'P109919', 'Daven', 119, Decimal('16.10024716')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P158289', 'Edward', 120, Decimal('16.19679941')),
#  ('M', 200, 'Medley', '3', 'U203', 'UoH', 'P716897', 'Alexander', 122, Decimal('16.32750494')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P503886', 'Chaya', 1, Decimal('12.85445561')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P393193', 'Charline', 2, Decimal('12.92320517')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P844138', 'Karen', 3, Decimal('13.11523755')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P776309', 'Maxine', 4, Decimal('13.18262387')),
#  ('F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P126715', 'Rebecca', 5, Decimal('13.3534012')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P308956', 'Stephanie', 6, Decimal('13.5318357')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P514806', 'Elizabeth', 7, Decimal('13.66351136')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P257391', 'Amanda', 8, Decimal('13.83855238')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P834447', 'Pamela', 9, Decimal('13.97600229')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P174047', 'Margaret', 10, Decimal('14.17246815')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P686988', 'Debra', 11, Decimal('14.27119624')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P779068', 'Barbara', 12, Decimal('14.34946009')),
#  ('F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P419077', 'Serena', 13, Decimal('14.47646258')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P561028', 'Xian', 14, Decimal('14.5793366')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P596208', 'Jennifer', 15, Decimal('14.62144151')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P422145', 'Rose', 16, Decimal('14.68704108')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P263690', 'Gina', 17, Decimal('14.84281111')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P870590', 'Biyu', 18, Decimal('15.03067638')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P650269', 'Gloria', 19, Decimal('15.17222658')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P938149', 'Aditi', 20, Decimal('15.23706728')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P402065', 'Lindsay', 21, Decimal('15.41220824')),
#  ('F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P326451', 'Lisa', 22, Decimal('15.50015794')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P503806', 'Ruth', 23, Decimal('15.68626948')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P146456', 'Akilah', 24, Decimal('15.76690657')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P744201', 'Betty', 25, Decimal('15.96249728')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P884623', 'Geneva', 26, Decimal('16.15926578')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P828862', 'Irma', 27, Decimal('16.25308419')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P108977', 'Anna', 28, Decimal('16.35778623')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P801697', 'Amy', 29, Decimal('16.52310095')),
#  ('F', 100, 'Backstroke', '1', 'U430', 'RICE', 'P896191', 'Elizabeth', 30, Decimal('16.60067915')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P251935', 'Frances', 31, Decimal('16.61680876')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P691294', 'Stephanie', 32, Decimal('17.07473989')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P831119', 'Xi', 33, Decimal('17.15676598')),
#  ('F', 100, 'Backstroke', '1', 'U203', 'UoH', 'P263779', 'Catheine', 34, Decimal('17.25046277')),
#  ('F', 100, 'Backstroke', '1', 'U502', 'UTDallas', 'P187734', 'Mary', 35, Decimal('17.36299494')),
#  ('F', 100, 'Backstroke', '1', 'U693', 'Baylor', 'P354503', 'Patricia', 36, Decimal('17.47486193')),
#  ('F', 100, 'Backstroke', '1', 'U422', 'UTAustin', 'P451746', 'Chunhua', 37, Decimal('17.48222495')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P831119', 'Xi', 1, Decimal('9.859423887')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P834447', 'Pamela', 2, Decimal('10.2721285')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P710107', 'Donny', 5, Decimal('10.4634547')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P776309', 'Maxine', 7, Decimal('10.60252782')),
#  ('M', 200, 'Butterfly', '1', 'U502', 'UTDallas', 'P126715', 'Rebecca', 10, Decimal('10.96157841')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P713611', 'Winter', 12, Decimal('10.99641683')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P722618', 'Yolanda', 15, Decimal('11.36255692')),
#  ('M', 200, 'Butterfly', '1', 'U502', 'UTDallas', 'P544348', 'Sophie', 19, Decimal('11.72588196')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P146456', 'Akilah', 22, Decimal('11.90015748')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P787951', 'Dorothy', 24, Decimal('12.0619299')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P305399', 'Marian', 26, Decimal('12.17124938')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P862621', 'Mia', 28, Decimal('12.50662921')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P552426', 'Xilin', 30, Decimal('12.67586018')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P691294', 'Stephanie', 32, Decimal('12.80430332')),
#  ('M', 200, 'Butterfly', '1', 'U502', 'UTDallas', 'P326451', 'Lisa', 33, Decimal('12.84477865')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P239302', 'Patricia', 34, Decimal('12.93481546')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P884623', 'Geneva', 36, Decimal('13.05796')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P503806', 'Ruth', 37, Decimal('13.06026526')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P214547', 'Katherine', 40, Decimal('13.18105446')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P263690', 'Gina', 42, Decimal('13.29360855')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P975231', 'Kelsey', 44, Decimal('13.45039521')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P453891', 'Amanda', 46, Decimal('13.48831354')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P697891', 'Xu', 47, Decimal('13.5434612')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P892923', 'Carol', 49, Decimal('13.6184794')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P408363', 'Sandra', 50, Decimal('13.62515063')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P240255', 'Hansika', 53, Decimal('13.89769869')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P308956', 'Stephanie', 54, Decimal('13.89834312')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P951470', 'Sarah', 56, Decimal('13.95252119')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P759847', 'Victoria', 57, Decimal('14.00188864')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P385867', 'Wanda', 58, Decimal('14.07945219')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P938149', 'Aditi', 60, Decimal('14.16702315')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P514607', 'Agnes', 61, Decimal('14.19371855')),
#  ('M', 200, 'Butterfly', '1', 'U502', 'UTDallas', 'P477094', 'Joy', 62, Decimal('14.24559135')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P493853', 'Terry', 63, Decimal('14.28924884')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P484371', 'Natalie', 67, Decimal('14.40182841')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P282743', 'Samantha', 69, Decimal('14.6291895')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P163990', 'Ava', 71, Decimal('14.72692031')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P450947', 'Isabel', 72, Decimal('14.79776118')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P512304', 'Maria', 75, Decimal('14.90084718')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P893682', 'Xilin', 76, Decimal('14.9247555')),
#  ('M', 200, 'Butterfly', '1', 'U422', 'UTAustin', 'P595277', 'Alda', 77, Decimal('14.9768661')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P962214', 'Saya', 80, Decimal('15.38166605')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P896372', 'Mary', 81, Decimal('15.38537411')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P596208', 'Jennifer', 82, Decimal('15.45028972')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P628983', 'Ada', 83, Decimal('15.49659594')),
#  ('M', 200, 'Butterfly', '1', 'U502', 'UTDallas', 'P676479', 'Susan', 84, Decimal('15.65761945')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P132685', 'Ana Paula', 85, Decimal('15.76993692')),
#  ('M', 200, 'Butterfly', '1', 'U430', 'RICE', 'P744201', 'Betty', 86, Decimal('16.04007196')),
#  ('M', 200, 'Butterfly', '1', 'U203', 'UoH', 'P686988', 'Debra', 87, Decimal('16.16944443')),
#  ('M', 200, 'Butterfly', '1', 'U502', 'UTDallas', 'P772269', 'Janet', 88, Decimal('16.23765867')),
#  ('M', 200, 'Butterfly', '1', 'U693', 'Baylor', 'P198583', 'Natalie', 89, Decimal('16.36125561')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P782093', 'Diego', 3, Decimal('10.36443466')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P451875', 'Elijah', 4, Decimal('10.42511681')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P960306', 'Samuel', 6, Decimal('10.56950603')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P925991', 'Samuel', 8, Decimal('10.75608853')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P281029', 'Michael', 9, Decimal('10.90309275')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P667298', 'Martin', 11, Decimal('10.98066591')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P814834', 'Mason', 13, Decimal('11.07383795')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P123639', 'Matt', 14, Decimal('11.26241279')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P244567', 'Ethan', 16, Decimal('11.40775757')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P114140', 'Nikhil', 17, Decimal('11.59334509')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P478858', 'Neil', 18, Decimal('11.67927057')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P363719', 'Ethan', 20, Decimal('11.77839167')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P855086', 'Jeremy', 21, Decimal('11.88651764')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P619446', 'Lai', 23, Decimal('12.02471907')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P109919', 'Daven', 25, Decimal('12.11817717')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P581736', 'Aiden', 27, Decimal('12.28975713')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P350087', 'Nicolas', 29, Decimal('12.5316226')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P837450', 'Liam', 31, Decimal('12.74052442')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P307392', 'Michael', 35, Decimal('12.957561')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P853409', 'George', 38, Decimal('13.07306192')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P139417', 'Ye', 39, Decimal('13.13940342')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P966483', 'Aiden', 41, Decimal('13.21595562')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P852515', 'Jacob', 43, Decimal('13.3773915')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P615133', 'Jack', 45, Decimal('13.45466518')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P294836', 'Richard', 48, Decimal('13.59818685')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P362851', 'Carolyn', 51, Decimal('13.72238641')),
#  ('M', 200, 'Butterfly', '2', 'U430', 'RICE', 'P132246', 'Armaan', 52, Decimal('13.75667862')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P686315', 'Noah', 55, Decimal('13.94830597')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P948241', 'Ishaan', 59, Decimal('14.10645402')),
#  ('M', 200, 'Butterfly', '2', 'U422', 'UTAustin', 'P691951', 'Mohammad', 64, Decimal('14.30533724')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P490897', 'Rohan', 65, Decimal('14.36350799')),
#  ('M', 200, 'Butterfly', '2', 'U502', 'UTDallas', 'P551881', 'Ethan', 66, Decimal('14.39673016')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P857171', 'Sebastian', 68, Decimal('14.55907188')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P664643', 'John', 70, Decimal('14.71295141')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P627706', 'Aiden', 73, Decimal('14.83268054')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P674970', 'Santiago', 74, Decimal('14.84354777')),
#  ('M', 200, 'Butterfly', '2', 'U203', 'UoH', 'P420213', 'Augustin', 78, Decimal('15.02888843')),
#  ('M', 200, 'Butterfly', '2', 'U693', 'Baylor', 'P926423', 'Deven', 79, Decimal('15.24121473'))]

# %% [markdown]
# The output should say that it's connected.  If it doesn't, either you set up PostgreSQL incorrectly or used the wrong password.
#
# Finally, one quick check that everything's fine.  We'll create a small table of data.  The %%sql allows multiple lines of SQL code.

# %%
# %%sql
# -- Some SQL code
# DROP TABLE IF EXISTS test;
# CREATE TABLE test (id SERIAL, item INT);
# INSERT INTO test VALUES (default, 13);
# INSERT INTO test VALUES (default,29);
# Out:
# Done.
# Done.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO test VALUES (default, NULL);
# SELECT * FROM test;
# Out:
# 1 rows affected.
# 4 rows affected.
# [(1, 13), (2, 29), (3, None), (4, None)]
